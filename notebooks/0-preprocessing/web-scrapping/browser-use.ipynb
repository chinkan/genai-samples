# %% [markdown]
# # Browser-Use Agent Sample
#
# Enable AI to control your browser 🤖. Browser use is the easiest way to connect your AI agents with the browser.
#
# This notebook demonstrates how to leverage the Browser-Use agent, a powerful tool that allows Language Models (LLMs) to control a browser and interact with web content. It provides a seamless interface for AI-driven web browsing and data extraction.
#
# For comprehensive documentation and more information, visit the official GitHub repository:
# [https://github.com/browser-use/browser-use](https://github.com/browser-use/browser-use)
#
# In the following examples, we'll explore setting up and utilizing the Browser-Use agent to programmatically interact with websites and extract valuable information.

# %%
#Install required package
# %pip install browser-use langchain_openai
# Out:
# Requirement already satisfied: browser-use in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (0.1.29)
# Requirement already satisfied: langchain_openai in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (4.12.3)
# Requirement already satisfied: httpx>=0.27.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.28.1)
# Requirement already satisfied: langchain-anthropic==0.3.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.3.3)
# Requirement already satisfied: langchain-aws>=0.2.11 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.2.11)
# Requirement already satisfied: langchain-fireworks>=0.2.6 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.2.6)
# Requirement already satisfied: langchain-google-genai==2.0.8 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (2.0.8)
# Requirement already satisfied: langchain-ollama==0.2.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.2.2)
# Requirement already satisfied: langchain==0.3.14 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.3.14)
# Requirement already satisfied: lmnr>=0.4.53 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr[langchain]>=0.4.53->browser-use) (0.4.55)
# Requirement already satisfied: maincontentextractor>=0.0.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (0.0.4)
# Requirement already satisfied: playwright>=1.49.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (1.49.1)
# Requirement already satisfied: posthog>=3.7.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (3.10.0)
# Requirement already satisfied: pydantic>=2.10.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (2.10.6)
# Requirement already satisfied: python-dotenv>=1.0.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (1.0.1)
# Requirement already satisfied: requests>=2.32.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (2.32.3)
# Requirement already satisfied: setuptools>=75.8.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from browser-use) (75.8.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.30 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain_openai) (0.3.31)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain_openai) (1.60.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain_openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (3.11.11)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (2.2.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain==0.3.14->browser-use) (9.0.0)
# Requirement already satisfied: anthropic<1,>=0.41.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.3->browser-use) (0.45.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-anthropic==0.3.3->browser-use) (0.7.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-google-genai==2.0.8->browser-use) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-google-genai==2.0.8->browser-use) (0.8.4)
# Requirement already satisfied: ollama<1,>=0.4.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-ollama==0.2.2->browser-use) (0.4.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.12.3->browser-use) (2.6)
# Requirement already satisfied: anyio in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpx>=0.27.2->browser-use) (4.8.0)
# Requirement already satisfied: certifi in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpx>=0.27.2->browser-use) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpx>=0.27.2->browser-use) (1.0.7)
# Requirement already satisfied: idna in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpx>=0.27.2->browser-use) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.2->browser-use) (0.14.0)
# Requirement already satisfied: boto3>=1.35.74 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-aws>=0.2.11->browser-use) (1.36.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.30->langchain_openai) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.30->langchain_openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.30->langchain_openai) (4.12.2)
# Requirement already satisfied: fireworks-ai>=0.13.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langchain-fireworks>=0.2.6->browser-use) (0.15.12)
# Collecting argparse>=1.0 (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: deprecated>=1.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.2.17)
# Requirement already satisfied: grpcio<1.68.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.67.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.28.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.28.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-requests>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-sqlalchemy>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-threading>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.28.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.4.2)
# Requirement already satisfied: tqdm>=4.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (4.67.1)
# Requirement already satisfied: opentelemetry-instrumentation-langchain>=0.36.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lmnr[langchain]>=0.4.53->browser-use) (0.37.1)
# Requirement already satisfied: trafilatura>=1.6.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from maincontentextractor>=0.0.4->browser-use) (2.0.0)
# Requirement already satisfied: html2text>=2020.1.16 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from maincontentextractor>=0.0.4->browser-use) (2024.2.26)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (0.8.2)
# Requirement already satisfied: sniffio in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (1.3.1)
# Requirement already satisfied: greenlet==3.1.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from playwright>=1.49.0->browser-use) (3.1.1)
# Requirement already satisfied: pyee==12.0.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from playwright>=1.49.0->browser-use) (12.0.0)
# Requirement already satisfied: six>=1.5 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from posthog>=3.7.0->browser-use) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from posthog>=3.7.0->browser-use) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from posthog>=3.7.0->browser-use) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from posthog>=3.7.0->browser-use) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from pydantic>=2.10.4->browser-use) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from pydantic>=2.10.4->browser-use) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from requests>=2.32.3->browser-use) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from requests>=2.32.3->browser-use) (2.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.14->browser-use) (1.18.3)
# Requirement already satisfied: botocore<1.37.0,>=1.36.6 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from boto3>=1.35.74->langchain-aws>=0.2.11->browser-use) (1.36.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from boto3>=1.35.74->langchain-aws>=0.2.11->browser-use) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from boto3>=1.35.74->langchain-aws>=0.2.11->browser-use) (0.11.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from deprecated>=1.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.17.2)
# Requirement already satisfied: httpx-ws in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from fireworks-ai>=0.13.0->langchain-fireworks>=0.2.6->browser-use) (0.7.1)
# Requirement already satisfied: httpx_sse in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from fireworks-ai>=0.13.0->langchain-fireworks>=0.2.6->browser-use) (0.4.0)
# Requirement already satisfied: Pillow in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from fireworks-ai>=0.13.0->langchain-fireworks>=0.2.6->browser-use) (11.1.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (2.24.1rc1)
# Requirement already satisfied: google-api-python-client in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (2.159.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (2.38.0)
# Requirement already satisfied: protobuf in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (1.26.0rc1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.30->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14->browser-use) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.14->browser-use) (1.0.0)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.28.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.28.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.28.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.28.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-langchain>=0.36.1->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-langchain>=0.36.1->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-requests>=0.50b0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (0.50b0)
# Requirement already satisfied: courlan>=1.3.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (3.0.1)
# Requirement already satisfied: lxml>=5.3.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (5.3.0)
# Requirement already satisfied: babel>=2.16.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from courlan>=1.3.2->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (2.16.0)
# Requirement already satisfied: tld>=0.13 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from courlan>=1.3.2->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (0.13)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (4.9)
# Requirement already satisfied: dateparser>=1.1.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from htmldate>=1.9.2->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.28.0->lmnr>=0.4.53->lmnr[langchain]>=0.4.53->browser-use) (3.21.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (4.1.1)
# Requirement already satisfied: wsproto in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httpx-ws->fireworks-ai>=0.13.0->langchain-fireworks>=0.2.6->browser-use) (1.2.0)
# Requirement already satisfied: pytz in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (2024.2)
# Requirement already satisfied: tzlocal in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (5.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (1.67.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (3.2.1)
# Requirement already satisfied: lxml-html-clean in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura>=1.6.2->maincontentextractor>=0.0.4->browser-use) (0.4.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.8->browser-use) (0.6.1)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup playwright
# !playwright install
# Out:
# Downloading Chromium 131.0.6778.33 (playwright build v1148) from https://playwright.azureedge.net/builds/chromium/1148/chromium
iB [=============       ] 66% 4.7s67.4 MiB [=============       ] 67% 4.6s67.4 MiB [==============      ] 68% 4.3s67.4 MiB [==============      ] 69% 4.1s67.4 MiB [==============      ] 70% 4.0s67.4 MiB [==============      ] 71% 3.8s67.4 MiB [==============      ] 72% 3.6s67.4 MiB [===============     ] 73% 3.5s67.4 MiB [===============     ] 74% 3.4s67.4 MiB [===============     ] 75% 3.2s67.4 MiB [===============     ] 76% 2.9s67.4 MiB [================    ] 78% 2.7s67.4 MiB [================    ] 79% 2.4s67.4 MiB [================    ] 81% 2.3s67.4 MiB [================    ] 82% 2.1s67.4 MiB [=================   ] 83% 2.2s67.4 MiB [=================   ] 84% 2.1s67.4 MiB [=================   ] 85% 1.9s67.4 MiB [=================   ] 86% 1.8s67.4 MiB [=================   ] 86% 1.7s67.4 MiB [==================  ] 87% 1.5s67.4 MiB [==================  ] 89% 1.4s67.4 MiB [==================  ] 90% 1.2s67.4 MiB [==================  ] 91% 1.0s67.4 MiB [=================== ] 93% 0.8s67.4 MiB [=================== ] 94% 0.7s67.4 MiB [=================== ] 95% 0.5s67.4 MiB [=================== ] 97% 0.4s67.4 MiB [====================] 98% 0.2s67.4 MiB [====================] 99% 0.0s67.4 MiB [====================] 100% 0.0s
# Webkit 18.2 (playwright build v2104) downloaded to /Users/kan/Library/Caches/ms-playwright/webkit-2104
# Downloading FFMPEG playwright build v1010 from https://playwright.azureedge.net/builds/ffmpeg/1010/ffmpeg-mac.zip
# 1.3 MiB [                    ] 1% 0.0s1.3 MiB [=============       ] 62% 0.0s1.3 MiB [====================] 100% 0.0s
# FFMPEG playwright build v1010 downloaded to /Users/kan/Library/Caches/ms-playwright/ffmpeg-1010

# %% [markdown]
# ## Choose LLM
#
# For this example, we'll use Azure OpenAI as our Language Model provider. However, Browser-Use is flexible and can work with various LLM clients. Here are a few options:
#
# 1. OpenAI
# 2. Azure OpenAI (used in this example)
# 3. DeepSeek-R1 (recently supported)
# ...
#
# Choose the LLM client that best suits your needs and API access. Make sure to adjust the import statement and initialization accordingly.
#
# Note: Remember to set up your environment variables or API keys for the chosen LLM provider before running the code.

# %%
# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# OpenAI 
# from langchain_openai import ChatOpenAI
# openai = ChatOpenAI(model="gpt-4o")

# Azure OpenAI
from langchain_openai import AzureChatOpenAI
openai = AzureChatOpenAI(model='gpt-4o', api_version='2024-02-15-preview')

# %%
# Initialize Tasks (any task can be used in native language)
task = "Go to TechCrunch and find the first news about AI"

# Initialize Agent
from browser_use import Agent

agent = Agent(
    task=task, # Task description
    llm=openai # Language model
)

# Run Agent
result = await agent.run()
print(result)
# Out:
# INFO     [agent] 🚀 Starting task: Go to TechCrunch and find the first news about AI
# INFO     [agent]
# 📍 Step 1
# INFO     [agent] 👍 Eval: Success - The browser is open and ready for interaction.
# INFO     [agent] 🧠 Memory: Opened a blank tab, need to navigate to TechCrunch.
# INFO     [agent] 🎯 Next goal: Navigate to TechCrunch's website to look for the news.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://techcrunch.com"}}
# INFO     [controller] 🔗  Navigated to https://techcrunch.com
# INFO     [agent]
# 📍 Step 2
# INFO     [agent] 👍 Eval: Success - Navigated to the TechCrunch website.
# INFO     [agent] 🧠 Memory: Browsing on TechCrunch, looking for AI news.
# INFO     [agent] 🎯 Next goal: Identify the first news related to AI and extract it.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":25}}
# INFO     [controller] 🖱️  Clicked button with index 25: Why Reid Hoffman feels optimistic about our AI future
# INFO     [agent]
# 📍 Step 3
# INFO     [agent] 👍 Eval: Success - The article about 'Why Reid Hoffman feels optimistic about our AI future' was successfully located and accessed.
# INFO     [agent] 🧠 Memory: Found and accessed the article 'Why Reid Hoffman feels optimistic about our AI future'.
# INFO     [agent] 🎯 Next goal: Complete the task by providing the relevant article details.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"Found the first AI-related news article on TechCrunch: 'Why Reid Hoffman feels optimistic about our AI future' published by Anthony Ha on January 26, 2025."}}
# INFO     [agent] 📄 Result: Found the first AI-related news article on TechCrunch: 'Why Reid Hoffman feels optimistic about our AI future' published by Anthony Ha on January 26, 2025.
# INFO     [agent] ✅ Task completed successfully
# INFO     [agent] Created GIF at agent_history.gif
# AgentHistoryList(all_results=[ActionResult(is_done=False, extracted_content='🔗  Navigated to https://techcrunch.com', error=None, include_in_memory=True), ActionResult(is_done=False, extracted_content='🖱️  Clicked button with index 25: Why Reid Hoffman feels optimistic about our AI future', error=None, include_in_memory=True), ActionResult(is_done=True, extracted_content="Found the first AI-related news article on TechCrunch: 'Why Reid Hoffman feels optimistic about our AI future' published by Anthony Ha on January 26, 2025.", error=None, include_in_memory=False)], all_model_outputs=[{'go_to_url': {'url': 'https://techcrunch.com'}}, {'click_element': {'index': 25}}, {'done': {'text': "Found the first AI-related news article on TechCrunch: 'Why Reid Hoffman feels optimistic about our AI future' published by Anthony Ha on January 26, 2025."}}])

# %% [markdown]
# ## Running the Browser-Use Agent
#
# When you execute the code above, you'll see the following process:
#
# 1. A Chromium browser window will open automatically.
# 2. The browser will navigate to the TechCrunch website (https://techcrunch.com).
# 3. The AI agent will search for and identify the first news article related to AI.
# 4. Once found, the agent will extract the relevant information.
# 5. The browser window will close.
# 6. The extracted information will be returned and printed in the notebook.
#
# ![Screenshot](../../../data/screenshots/browser-use/screenshot-1.png)
#
# This automated process demonstrates the power of the Browser-Use agent in controlling a real browser to interact with web content and extract specific information based on the given task.
#
# Note: The actual browser window may flash briefly on your screen as the agent performs its task.

# %%
# make the task more difficult
task = "Go to booking.com and find the cheapest hotel in Okinawa for 2 nights from 2025-08-01 to 2025-08-03"

agent = Agent(
    task=task, # Task description
    llm=openai # Language model
)

result = await agent.run()
print(result)
# Out:
# INFO     [agent] 🚀 Starting task: Go to booking.com and find the cheapest hotel in Okinawa for 2 nights from 2025-08-01 to 2025-08-03
# INFO     [agent]
# 📍 Step 1
# INFO     [agent] 🤷 Eval: Unknown - The page is blank, no previous actions to evaluate.
# INFO     [agent] 🧠 Memory: Task requires searching for a hotel in Okinawa from 2025-08-01 to 2025-08-03 on Booking.com.
# INFO     [agent] 🎯 Next goal: Navigate to Booking.com.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.booking.com"}}
# INFO     [controller] 🔗  Navigated to https://www.booking.com
# INFO     [agent]
# 📍 Step 2
# INFO     [agent] 👍 Eval: Success - Successfully navigated to Booking.com.
# INFO     [agent] 🧠 Memory: On Booking.com homepage, need to fill in location and date details to search for hotel in Okinawa.
# INFO     [agent] 🎯 Next goal: Initiate a search for hotels in Okinawa including setting check-in and check-out dates.
# INFO     [agent] 🛠️  Action 1/3: {"click_element":{"index":32}}
# INFO     [agent] 🛠️  Action 2/3: {"input_text":{"index":0,"text":"Okinawa"}}
# INFO     [agent] 🛠️  Action 3/3: {"send_keys":{"keys":"Enter"}}
# INFO     [controller] 🖱️  Clicked button with index 32:
# INFO     [controller] Something new appeared after action 1 / 3
# INFO     [agent]
# 📍 Step 3
# INFO     [agent] ⚠ Eval: Failed - The text input action was not executed; hence, no text was written and no search initiated.
# INFO     [agent] 🧠 Memory: Attempting to search for hotels in Okinawa from 2025-08-01 to 2025-08-03 on Booking.com.
# INFO     [agent] 🎯 Next goal: Retry setting location as Okinawa and other search filters including dates.
# INFO     [agent] 🛠️  Action 1/10: {"input_text":{"index":19,"text":"Okinawa"}}
# INFO     [agent] 🛠️  Action 2/10: {"send_keys":{"keys":"Enter"}}
# INFO     [agent] 🛠️  Action 3/10: {"click_element":{"index":21}}
# INFO     [agent] 🛠️  Action 4/10: {"send_keys":{"keys":"2"}}
# INFO     [agent] 🛠️  Action 5/10: {"send_keys":{"keys":"0"}}
# INFO     [agent] 🛠️  Action 6/10: {"send_keys":{"keys":"2"}}
# INFO     [agent] 🛠️  Action 7/10: {"send_keys":{"keys":"5"}}
# INFO     [agent] 🛠️  Action 8/10: {"send_keys":{"keys":"0"}}
# INFO     [agent] 🛠️  Action 9/10: {"send_keys":{"keys":"8"}}
# INFO     [agent] 🛠️  Action 10/10: {"send_keys":{"keys":"0"}}
# INFO     [controller] ⌨️  Input "Okinawa" into index 19
# INFO     [controller] ⌨️  Sent keys: Enter
# INFO     [controller] Something new appeared after action 2 / 10
# INFO     [agent]
# 📍 Step 4
# INFO     [agent] 👍 Eval: Success - Location set as Okinawa and initiated the search for hotels.
# INFO     [agent] 🧠 Memory: Continuing to find a hotel in Okinawa for specified dates.
# INFO     [agent] 🎯 Next goal: Set check-in and check-out dates to 2025-08-01 and 2025-08-03.
# INFO     [agent] 🛠️  Action 1/5: {"click_element":{"index":21}}
# INFO     [agent] 🛠️  Action 2/5: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/5: {"click_element":{"index":88}}
# INFO     [agent] 🛠️  Action 4/5: {"click_element":{"index":90}}
# INFO     [agent] 🛠️  Action 5/5: {"click_element":{"index":95}}
# INFO     [controller] 🖱️  Clicked button with index 21: Check-in Date
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] Something new appeared after action 2 / 5
# INFO     [agent]
# 📍 Step 5
# INFO     [agent] 👍 Eval: Success - Location is set, properties are loaded. Dates need verification.
# INFO     [agent] 🧠 Memory: Continuing search for cheapest hotel in Okinawa from 2025-08-01 to 2025-08-03 in Booking.com.
# INFO     [agent] 🎯 Next goal: Check available prices and sort for cheapest option.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":122}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":130}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":139}}
# INFO     [agent] 🛠️  Action 4/4: {"scroll_down":{}}
# INFO     [controller] 🖱️  Clicked button with index 122: Show prices
# INFO     [controller] Something new appeared after action 1 / 4
# INFO     [agent]
# 📍 Step 6
# INFO     [agent] 👍 Eval: Success - Prices are shown but not sorted by the cheapest yet.
# INFO     [agent] 🧠 Memory: Currently on the search results page for hotels in Okinawa. Date settings and search were successful.
# INFO     [agent] 🎯 Next goal: Find and sort the hotel list by price to identify the cheapest option.
# INFO     [agent] 🛠️  Action 1/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":17}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":98}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":95}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] Something new appeared after action 1 / 4
# INFO     [agent]
# 📍 Step 7
# INFO     [agent] ⚠ Eval: Failed - Did not filter hotels by cheapest price.
# INFO     [agent] 🧠 Memory: The search results for hotels in Okinawa are loaded, dates updated, now need to find/filter for the cheapest option.
# INFO     [agent] 🎯 Next goal: Investigate if price sorting options are available or mentioned on the page.
# INFO     [agent] 🛠️  Action 1/5: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/5: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/5: {"click_element":{"index":155}}
# INFO     [agent] 🛠️  Action 4/5: {"click_element":{"index":164}}
# INFO     [agent] 🛠️  Action 5/5: {"click_element":{"index":172}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action click_element: Element with index 155 does not exist - retry or use alternative actions
# INFO     [agent]
# 📍 Step 8
# INFO     [agent] ⚠ Eval: Failed - Could not locate the sorting element for filtering by price.
# INFO     [agent] 🧠 Memory: The listings page is loaded for hotels in Okinawa, attempting a search filter to find the lowest price.
# INFO     [agent] 🎯 Next goal: Attempt an alternative approach to find the cheapest option, like scrolling to extract more data.
# INFO     [agent] 🛠️  Action 1/3: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/3: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/3: {"extract_content":{"include_links":false}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 📄  Extracted page as text
# : Right on the beach next to Itoman Port, Southern Beach Hotel & Resort features 2 pools and an ocean-view buffet restaurant. Rooms have a balcony with ocean views.Located in Ginowan, a 9-minute walk from Tropical Beach, Okinawa Prince Hotel Ocean View Ginowan has accommodations with an outdoor swimming pool, free private parking, a fitness center and a terrace....Located a 20-minute drive from Sunset Beach, EM Wellness Living's Fermented Lifestyle Resort features a sun-filled spa, 3 dining options, a sauna and relaxing rooms with free wifi and balconies.Located on the beach front, Best Western Okinawa Kouki Beach offers rooms with ocean views and free WiFi access. A range of water sport facilities is provided on-site.Located in Miyako-jima, within a 1-minute walk of Waiwai Beach and half a mile of Shigira Beach, HOTEL SEABREEZE CORAL provides accommodations with an outdoor swimming pool and free WiFi throughout...Katsuren Seatopia 勝連シートピア offers accommodations in Uruma, 1.1 miles from Katsuren Castle and 2.8 miles from Yakena Bus Terminal. This property offers access to a terrace and free private parking.Located in Tomigusuku, a few steps from Senaga Beach, THE SENAGAJIMA STORYLINE provides accommodations with a seasonal outdoor swimming pool, free private parking, a fitness center and a terrace.Located in Yomitan, a 8-minute walk from Sobe Beach, Umi No Terrace Yomitan Toya has accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Rizo Zaizen Hotel offers accommodations in Ginowan, one mile from Tropical Beach and 5.5 miles from Nakagusuku Castle. With sea views, this accommodation offers a balcony.Located in Chatan, a 14-minute walk from Sunset Beach, Aqua Palace Chatan by Coldio Premium has accommodations with an outdoor swimming pool, free private parking, a terrace and a restaurant.Located right in front of the beautiful Nirai Beach, Hotel Nikko Alivila is luxurious resort accommodations with spacious guest rooms, a spa salon and an indoor swimming pool.Offering free WiFi throughout the property, Hotel Santa Barbara Miyakojima Resort is located in Miyako-jima, 4.2 miles from Ueno German Culture Village and 4.8 miles from Turiba Seaside Park.Located in Nakijin, a 5-minute walk from Chigunu Beach, Private condo Kourijima by Coldio Smart Resort has accommodations with a garden, free private parking, a terrace and a restaurant.Kafuu Resort Fuchaku Condo Hotel offers luxurious rooms with a balcony and ocean views. It features an outdoor pool, a 24-hour fitness center and 3 restaurants.Boasting a magnificent view of the ocean, Best Western Okinawa Onna Beach is located just a minute away from Emerald Beach. Free WiFi and an internet PC are available at the lobby.Located in Motobu, a 17-minute walk from Lover's Beach Ufuta-hama, Hoshi No Terrace Motobu Yamazato has accommodations with a garden, free private parking, a shared lounge and a terrace.Located in Onna, a 16-minute walk from Sun Marina Beach, AQUASENSE Hotel & Resort has accommodations with a seasonal outdoor swimming pool, free private parking and a restaurant.Located in Onna, a few steps from Kariyushi Beach, Odysis Onna Resort Hotel provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Kaiza in Nanjo provides adults-only accommodations with a garden and a shared lounge. This 2-star bed and breakfast offers luggage storage space and bicycle parking.HOTEL HOUKLEA offers accommodations in Nago, 1.7 miles from Umusa Beach and 1.8 miles from 21st Century Forest Beach. Guests staying at this condo hotel have access to a balcony.Just a 5-minute walk from Maehama Beach and 1.2 miles from Kurima Bridge, GLOCE 宮古島 LAPSI 与那覇前浜Beachまで徒歩5分の オーナー同居型ゲストハウス features accommodations in Yonaha with a garden.Located in Onna, a few steps from Hamabaru Beach, La Casa Panacea Okinawa Resort provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a sh ...
#
# INFO     [agent]
# 📍 Step 9
# INFO     [agent] 🤷 Eval: Unknown - Need to check the current state of whether prices are sorted or visible.
# INFO     [agent] 🧠 Memory: Scrolled through Okinawa hotel listings but need to identify the cheapest available option.
# INFO     [agent] 🎯 Next goal: Identify the cheapest hotel by manually searching through currently visible listings.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":20}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":28}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":36}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":44}}
# INFO     [controller] 🖱️  Clicked button with index 20: Show prices
# INFO     [controller] Something new appeared after action 1 / 4
# INFO     [agent]
# 📍 Step 10
# INFO     [agent] 🤷 Eval: Unknown - Prices visibility not confirmed, interaction sequence incomplete.
# INFO     [agent] 🧠 Memory: Located multiple hotels in Okinawa, need to reveal prices for filtering cheapest one, visible listings require checking prices.
# INFO     [agent] 🎯 Next goal: Continue actions to show hotel prices and extract to identify the cheapest.
# INFO     [agent] 🛠️  Action 1/3: {"click_element":{"index":168}}
# INFO     [agent] 🛠️  Action 2/3: {"click_element":{"index":176}}
# INFO     [agent] 🛠️  Action 3/3: {"extract_content":{"include_links":false}}
ides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a sh ...
#
# INFO     [agent]
# 📍 Step 11
# INFO     [agent] 👍 Eval: Success - Navigated to specific hotel page indicating pricing details interaction was successful.
# INFO     [agent] 🧠 Memory: Currently on Okinawa Prince Hotel Ocean View Ginowan's page. Need to find pricing details or return to search results for cheapest hotel identification.
# INFO     [agent] 🎯 Next goal: Check this hotel's prices and see if it's the cheapest option or return to overview of options.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"include_links":false}}
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action extract_content: mismatched tag: line 103, column 74
# INFO     [agent]
# 📍 Step 12
# INFO     [agent] ⚠ Eval: Failed - Could not extract prices and availability successfully from the current hotel page.
# INFO     [agent] 🧠 Memory: Stuck on a specific hotel page for Okinawa Prince Hotel Ocean View Ginowan without price extraction capability.
# INFO     [agent] 🎯 Next goal: Return to the original search results page to switch and potentially sort listings, aiming for the lowest price hotel identification.
# INFO     [agent] 🛠️  Action 1/1: {"switch_tab":{"page_id":0}}
# INFO     [controller] 🔄  Switched to tab 0
# INFO     [agent]
# 📍 Step 13
# INFO     [agent] 🤷 Eval: Unknown - Returning to the search page was successful, but preferred price listings are not confirmed yet.
# INFO     [agent] 🧠 Memory: Returned to search results on Booking.com for Okinawa hotels, still need cheapest option.
# INFO     [agent] 🎯 Next goal: Continue extraction attempts, focus on interface to locate sorting or visible lowest pricing.
# INFO     [agent] 🛠️  Action 1/4: {"extract_content":{"include_links":false}}
# INFO     [agent] 🛠️  Action 2/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":138}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":147}}
# INFO     [controller] 📄  Extracted page as text
# : Right on the beach next to Itoman Port, Southern Beach Hotel & Resort features 2 pools and an ocean-view buffet restaurant. Rooms have a balcony with ocean views.Located in Ginowan, a 9-minute walk from Tropical Beach, Okinawa Prince Hotel Ocean View Ginowan has accommodations with an outdoor swimming pool, free private parking, a fitness center and a terrace....Located a 20-minute drive from Sunset Beach, EM Wellness Living's Fermented Lifestyle Resort features a sun-filled spa, 3 dining options, a sauna and relaxing rooms with free wifi and balconies.Located on the beach front, Best Western Okinawa Kouki Beach offers rooms with ocean views and free WiFi access. A range of water sport facilities is provided on-site.Located in Miyako-jima, within a 1-minute walk of Waiwai Beach and half a mile of Shigira Beach, HOTEL SEABREEZE CORAL provides accommodations with an outdoor swimming pool and free WiFi throughout...Katsuren Seatopia 勝連シートピア offers accommodations in Uruma, 1.1 miles from Katsuren Castle and 2.8 miles from Yakena Bus Terminal. This property offers access to a terrace and free private parking.Located in Tomigusuku, a few steps from Senaga Beach, THE SENAGAJIMA STORYLINE provides accommodations with a seasonal outdoor swimming pool, free private parking, a fitness center and a terrace.Located in Yomitan, a 8-minute walk from Sobe Beach, Umi No Terrace Yomitan Toya has accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Rizo Zaizen Hotel offers accommodations in Ginowan, one mile from Tropical Beach and 5.5 miles from Nakagusuku Castle. With sea views, this accommodation offers a balcony.Located in Chatan, a 14-minute walk from Sunset Beach, Aqua Palace Chatan by Coldio Premium has accommodations with an outdoor swimming pool, free private parking, a terrace and a restaurant.Located right in front of the beautiful Nirai Beach, Hotel Nikko Alivila is luxurious resort accommodations with spacious guest rooms, a spa salon and an indoor swimming pool.Offering free WiFi throughout the property, Hotel Santa Barbara Miyakojima Resort is located in Miyako-jima, 4.2 miles from Ueno German Culture Village and 4.8 miles from Turiba Seaside Park.Located in Nakijin, a 5-minute walk from Chigunu Beach, Private condo Kourijima by Coldio Smart Resort has accommodations with a garden, free private parking, a terrace and a restaurant.Kafuu Resort Fuchaku Condo Hotel offers luxurious rooms with a balcony and ocean views. It features an outdoor pool, a 24-hour fitness center and 3 restaurants.Boasting a magnificent view of the ocean, Best Western Okinawa Onna Beach is located just a minute away from Emerald Beach. Free WiFi and an internet PC are available at the lobby.Located in Motobu, a 17-minute walk from Lover's Beach Ufuta-hama, Hoshi No Terrace Motobu Yamazato has accommodations with a garden, free private parking, a shared lounge and a terrace.Located in Onna, a 16-minute walk from Sun Marina Beach, AQUASENSE Hotel & Resort has accommodations with a seasonal outdoor swimming pool, free private parking and a restaurant.Located in Onna, a few steps from Kariyushi Beach, Odysis Onna Resort Hotel provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Kaiza in Nanjo provides adults-only accommodations with a garden and a shared lounge. This 2-star bed and breakfast offers luggage storage space and bicycle parking.HOTEL HOUKLEA offers accommodations in Nago, 1.7 miles from Umusa Beach and 1.8 miles from 21st Century Forest Beach. Guests staying at this condo hotel have access to a balcony.Just a 5-minute walk from Maehama Beach and 1.2 miles from Kurima Bridge, GLOCE 宮古島 LAPSI 与那覇前浜Beachまで徒歩5分の オーナー同居型ゲストハウス features accommodations in Yonaha with a garden.Located in Onna, a few steps from Hamabaru Beach, La Casa Panacea Okinawa Resort provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a sh ...
#
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🖱️  Clicked button with index 138:
# WARNING  [controller] Element not clickable with index 147 - most likely the page changed
# INFO     [agent]
# 📍 Step 14
# INFO     [agent] 🤷 Eval: Unknown - navigated to a specific hotel's page for Villa SACHIIBARU in Nanjo, still missing a clear price comparison.
# INFO     [agent] 🧠 Memory: Failed to extract or review effective price listings. Last known was searching price details in hotel specific pages.
# INFO     [agent] 🎯 Next goal: Identify price details below the scrolling line and decide if it differs from previously viewed options.
# INFO     [agent] 🛠️  Action 1/2: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/2: {"extract_content":{"include_links":false}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action extract_content: mismatched tag: line 100, column 53
# INFO     [agent]
# 📍 Step 15
# INFO     [agent] ⚠ Eval: Failed - Couldn't retrieve the price yet and ended up on a page without extraction capabilities.
# INFO     [agent] 🧠 Memory: Navigated to Villa SACHIIBARU page unsuccessfully, resuming this visit will not yield results.
# INFO     [agent] 🎯 Next goal: Return again to primary search results for better price comparison and searches already available.
# INFO     [agent] 🛠️  Action 1/1: {"switch_tab":{"page_id":0}}
# INFO     [controller] 🔄  Switched to tab 0
# INFO     [agent]
# 📍 Step 16
# INFO     [agent] ⚠ Eval: Failed - Unable to find pricing details for all hotels or sort reliably on current options visibility.
# INFO     [agent] 🧠 Memory: Returning encountered pages with unique hotel experiences without price filtering and insight required for Okinawa hotel raw extraction.
# INFO     [agent] 🎯 Next goal: Toggle 'Show all' or resort elements to provide access, completing price identification for cheapest options.
# INFO     [agent] 🛠️  Action 1/3: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/3: {"click_element":{"index":120}}
# INFO     [agent] 🛠️  Action 3/3: {"click_element":{"index":128}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🖱️  Clicked button with index 120:
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action click_element: Element with index 128 does not exist - retry or use alternative actions
# INFO     [agent]
# 📍 Step 17
# INFO     [agent] ⚠ Eval: Failed - current actions did not lead to identifying the cheapest hotel
# INFO     [agent] 🧠 Memory: Hotel details are visible but no effective pricing for comparison.
# INFO     [agent] 🎯 Next goal: Extract content to find & verify cheapest details or arrange sorting at least for clarity.
# INFO     [agent] 🛠️  Action 1/7: {"extract_content":{"include_links":true}}
# INFO     [agent] 🛠️  Action 2/7: {"switch_tab":{"page_id":0}}
# INFO     [agent] 🛠️  Action 3/7: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 4/7: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 5/7: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 6/7: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 7/7: {"extract_content":{"include_links":false}}
# ERROR    [agent] ❌ Result failed 2/3 times:
#  Error executing action extract_content: mismatched tag: line 82, column 66
# INFO     [agent]
# 📍 Step 18
# INFO     [agent] ⚠ Eval: Failed - Task was to find the overall cheapest hotel; instead, detailed room page with no success in price checks.
# INFO     [agent] 🧠 Memory: On 'Umi No Terrace Yomitan Toya' hotel page, multiple attempts failed at identifying cheapest overall options in Okinawa hotels context.
# INFO     [agent] 🎯 Next goal: Return to search tab window and attempt reconfiguring sort order for visible cheapest options.
# INFO     [agent] 🛠️  Action 1/3: {"switch_tab":{"page_id":0}}
# INFO     [agent] 🛠️  Action 2/3: {"click_element":{"index":97}}
# INFO     [agent] 🛠️  Action 3/3: {"extract_content":{"include_links":true}}
# INFO     [controller] 🔄  Switched to tab 0
# INFO     [controller] Something new appeared after action 1 / 3
# INFO     [agent]
# 📍 Step 19
# INFO     [agent] ⚠ Eval: Failed - Didn't manage to filter or identify a sort function for cheapest options.
# INFO     [agent] 🧠 Memory: Listings are fully showcased yet unrated past view from real sorted pricing availability.
# INFO     [agent] 🎯 Next goal: Try visible price extraction, final attempt can give revealing relevant cheap info if maximum scroll achieved.
# INFO     [agent] 🛠️  Action 1/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 2/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 4/4: {"extract_content":{"include_links":true}}
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 📄  Extracted page as markdown
# : Right on the beach next to Itoman Port, Southern Beach Hotel & Resort features
# 2 pools and an ocean-view buffet restaurant. Rooms have a balcony with ocean
# views.
#
# Located in Ginowan, a 9-minute walk from Tropical Beach, Okinawa Prince Hotel
# Ocean View Ginowan has accommodations with an outdoor swimming pool, free
# private parking, a fitness center and a terrace....
#
# Located a 20-minute drive from Sunset Beach, EM Wellness Living's Fermented
# Lifestyle Resort features a sun-filled spa, 3 dining options, a sauna and
# relaxing rooms with free wifi and balconies.
#
# Located on the beach front, Best Western Okinawa Kouki Beach offers rooms with
# ocean views and free WiFi access. A range of water sport facilities is
# provided on-site.
#
# Located in Miyako-jima, within a 1-minute walk of Waiwai Beach and half a mile
# of Shigira Beach, HOTEL SEABREEZE CORAL provides accommodations with an
# has free bikes, free WiFi and a restaurant. This 3-star hotel offers a 24-hour
# front desk and luggage storage space.
#
# Well located in Naha, Toyoko Inn Okinawa Naha Asahibashi Ekimae provides a
# buffet breakfast and free WiFi. This 3-star hotel offers a 24-hour front desk.
# Private parking is available on site.
#
# A 7-minute walk from Ishigaki Port Ricoh Ferry Terminal and a 3-minute drive
# from the beach, Hotel Patina Ishigakijima offers cozy rooms with hardwood
# floors, free internet and a private balcony.
#
# Located in Henza, within 1.7 miles of Hamahiga Beach and 3.4 miles of Yakena
# Bus Terminal, Umi no Yado Umikaze provides accommodations with a garden and
# free WiFi as well as free private parking for...
#
# A 15-minute walk from the vibrant Kokusai Dori Street, Libre Garden features a
# garden, an Italian restaurant and free Wi-Fi throughout the property. It
# offers contemporary rooms with a classical...
#
# We have more than 70 million property reviews, all from real, verified guests.
#
# How does it work?
#
# 1
#
# It starts with a booking
#
# It starts with a booking
#
# The only way to leave a review is to first make a booking. That's how we know
# our reviews come from real guests who have stayed at the property.
#
# 2
#
# Followed by a trip
#
# Followed by a trip
#
# When guests stay at the property, they check out how quiet the room is, how
# friendly the staff is, and more.
#
# 3
#
# And finally, a review
#
# And finally, a review
#
# After their trip, guests tell us about their stay. We check for naughty words
# and verify the authenticity of all guest reviews before adding them to our
# site.
#
# If you booked through us and want to leave a review, please sign in first.
#
#
#
# INFO     [agent]
# 📍 Step 20
# INFO     [agent] 🤷 Eval: Partial success - Able to spot 'show prices' buttons but couldn't extract directly due to tag discrepancies and incomplete scrolling for cheapest offering.
# INFO     [agent] 🧠 Memory: Located listings of several hotels, scrolling has revealed several 'Show prices' buttons but without successful extraction.
# INFO     [agent] 🎯 Next goal: Attempt to click 'Show prices' for each relevant hotel to reveal cost and potentially extract cheapest visibility.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":28}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":36}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":44}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":52}}
# INFO     [controller] 🖱️  Clicked button with index 28: Show prices
# INFO     [controller] Something new appeared after action 1 / 4
# INFO     [agent]
# 📍 Step 21
# INFO     [agent] ⚠ Eval: Failed - The task of finding the cheapest hotel remains incomplete. Show price buttons are visible but efficient extraction yet needed.
# INFO     [agent] 🧠 Memory: Current interaction history focused on getting the lowest player within extensive list moments, needing extra extraction specifics.
# INFO     [agent] 🎯 Next goal: Methodically go through available 'Show prices' buttons for appropriate visibility and primary task accuracy.
# INFO     [agent] 🛠️  Action 1/2: {"click_element":{"index":168}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element":{"index":176}}
# INFO     [controller] 🖱️  Clicked button with index 168: Show prices
# INFO     [controller] 🖱️  Clicked button with index 176:
# INFO     [agent]
# 📍 Step 22
# INFO     [agent] ⚠ Eval: Failed - Continues to price show button interactions, no effective capture of cheapest hotel pricing achieved.
# INFO     [agent] 🧠 Memory: Maintained interaction history across multiple scrolling experiences, yet visible cheapest option remains undetermined from action.
# INFO     [agent] 🎯 Next goal: Redirect focus on any available price, extract methods encompassing recent element indexes.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":122}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":130}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":138}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":147}}
# WARNING  [controller] Element not clickable with index 122 - most likely the page changed
# INFO     [agent]
# 📍 Step 23
# INFO     [agent] ⚠ Eval: Failed - Numerous attempts to extract price data or sort listings have failed.
# INFO     [agent] 🧠 Memory: Continuous attempts to focus on finding the cheapest hotel for given dates weren’t satisfied on several extraction points.
# INFO     [agent] 🎯 Next goal: Address the issue of price visibility by consolidating into search result page checks one more time.
# INFO     [agent] 🛠️  Action 1/1: {"switch_tab":{"page_id":0}}
# INFO     [controller] 🔄  Switched to tab 0
# INFO     [agent]
# 📍 Step 24
# INFO     [agent] 👍 Eval: Success - Retrieved search results for Okinawa hotels on visible scope.
# INFO     [agent] 🧠 Memory: Established @ Booking for Okinawa lodging for target dates without detailed price outcome.
# INFO     [agent] 🎯 Next goal: Effect interactive components for price indifications for the cheapest hotel.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":122}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":130}}
# INFO     [agent] 🛠️  Action 3/4: {"click_element":{"index":138}}
# INFO     [agent] 🛠️  Action 4/4: {"click_element":{"index":147}}
# INFO     [controller] 🖱️  Clicked button with index 122: Show prices
# INFO     [controller] Something new appeared after action 1 / 4
# INFO     [agent]
# 📍 Step 25
# INFO     [agent] 🤷 Eval: Partial success - Being on the search result page from Booking.com for hotels in Okinawa, some 'Show prices' successful clicks but extraction reliability insufficient.
# INFO     [agent] 🧠 Memory: Previous interactive techniques involved clicking, scrolling, and failing on extraction. However, a page shows all information live to click on productively.
# INFO     [agent] 🎯 Next goal: Conclude with the cheapest price hotel findings on active natural listings interface.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"include_links":false}}
# INFO     [controller] 📄  Extracted page as text
# : Right on the beach next to Itoman Port, Southern Beach Hotel & Resort features 2 pools and an ocean-view buffet restaurant. Rooms have a balcony with ocean views.Located in Ginowan, a 9-minute walk from Tropical Beach, Okinawa Prince Hotel Ocean View Ginowan has accommodations with an outdoor swimming pool, free private parking, a fitness center and a terrace....Located a 20-minute drive from Sunset Beach, EM Wellness Living's Fermented Lifestyle Resort features a sun-filled spa, 3 dining options, a sauna and relaxing rooms with free wifi and balconies.Located on the beach front, Best Western Okinawa Kouki Beach offers rooms with ocean views and free WiFi access. A range of water sport facilities is provided on-site.Located in Miyako-jima, within a 1-minute walk of Waiwai Beach and half a mile of Shigira Beach, HOTEL SEABREEZE CORAL provides accommodations with an outdoor swimming pool and free WiFi throughout...Katsuren Seatopia 勝連シートピア offers accommodations in Uruma, 1.1 miles from Katsuren Castle and 2.8 miles from Yakena Bus Terminal. This property offers access to a terrace and free private parking.Located in Tomigusuku, a few steps from Senaga Beach, THE SENAGAJIMA STORYLINE provides accommodations with a seasonal outdoor swimming pool, free private parking, a fitness center and a terrace.Located in Yomitan, a 8-minute walk from Sobe Beach, Umi No Terrace Yomitan Toya has accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Rizo Zaizen Hotel offers accommodations in Ginowan, one mile from Tropical Beach and 5.5 miles from Nakagusuku Castle. With sea views, this accommodation offers a balcony.Located in Chatan, a 14-minute walk from Sunset Beach, Aqua Palace Chatan by Coldio Premium has accommodations with an outdoor swimming pool, free private parking, a terrace and a restaurant.Located right in front of the beautiful Nirai Beach, Hotel Nikko Alivila is luxurious resort accommodations with spacious guest rooms, a spa salon and an indoor swimming pool.Offering free WiFi throughout the property, Hotel Santa Barbara Miyakojima Resort is located in Miyako-jima, 4.2 miles from Ueno German Culture Village and 4.8 miles from Turiba Seaside Park.Located in Nakijin, a 5-minute walk from Chigunu Beach, Private condo Kourijima by Coldio Smart Resort has accommodations with a garden, free private parking, a terrace and a restaurant.Kafuu Resort Fuchaku Condo Hotel offers luxurious rooms with a balcony and ocean views. It features an outdoor pool, a 24-hour fitness center and 3 restaurants.Boasting a magnificent view of the ocean, Best Western Okinawa Onna Beach is located just a minute away from Emerald Beach. Free WiFi and an internet PC are available at the lobby.Located in Motobu, a 17-minute walk from Lover's Beach Ufuta-hama, Hoshi No Terrace Motobu Yamazato has accommodations with a garden, free private parking, a shared lounge and a terrace.Located in Onna, a 16-minute walk from Sun Marina Beach, AQUASENSE Hotel & Resort has accommodations with a seasonal outdoor swimming pool, free private parking and a restaurant.Located in Onna, a few steps from Kariyushi Beach, Odysis Onna Resort Hotel provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a terrace.Kaiza in Nanjo provides adults-only accommodations with a garden and a shared lounge. This 2-star bed and breakfast offers luggage storage space and bicycle parking.HOTEL HOUKLEA offers accommodations in Nago, 1.7 miles from Umusa Beach and 1.8 miles from 21st Century Forest Beach. Guests staying at this condo hotel have access to a balcony.Just a 5-minute walk from Maehama Beach and 1.2 miles from Kurima Bridge, GLOCE 宮古島 LAPSI 与那覇前浜Beachまで徒歩5分の オーナー同居型ゲストハウス features accommodations in Yonaha with a garden.Located in Onna, a few steps from Hamabaru Beach, La Casa Panacea Okinawa Resort provides accommodations with a seasonal outdoor swimming pool, free private parking, a garden and a sh ...
#
# INFO     [agent]
# 📍 Step 26
# INFO     [agent] ⚠ Eval: Failed - The images provided pricing details from individual hotels but further traction relative to cheapest remains.
# INFO     [agent] 🧠 Memory: Process showcased a page that includes multiple visible interactions but no efficient outage in elucidating the cheapest option in sequence.
# INFO     [agent] 🎯 Next goal: Combining element interactions, subsequent extraction tags underlying findings, which may include scrolling for best cost performance.
# INFO     [agent] 🛠️  Action 1/4: {"click_element":{"index":168}}
# INFO     [agent] 🛠️  Action 2/4: {"click_element":{"index":176}}
# INFO     [agent] 🛠️  Action 3/4: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 4/4: {"extract_content":{"include_links":true}}
# INFO     [controller] 🖱️  Clicked button with index 168: Show prices
# INFO     [controller] 🖱️  Clicked button with index 176:
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 📄  Extracted page as markdown
# : Right on the beach next to Itoman Port, Southern Beach Hotel & Resort features
# 2 pools and an ocean-view buffet restaurant. Rooms have a balcony with ocean
# views.
#
# Located in Ginowan, a 9-minute walk from Tropical Beach, Okinawa Prince Hotel
# Ocean View Ginowan has accommodations with an outdoor swimming pool, free
# private parking, a fitness center and a terrace....
#
# Located a 20-minute drive from Sunset Beach, EM Wellness Living's Fermented
# Lifestyle Resort features a sun-filled spa, 3 dining options, a sauna and
# Resort provides accommodations with a seasonal outdoor swimming pool, free
# private parking, a garden and a shared lounge.
#
# Located in Onna and with Nakadomari Beach reachable within a 12-minute walk,
# Hotel Sunset Hill provides a terrace, non-smoking rooms, free WiFi and a
# restaurant.
#
# Hotel androoms Naha Port is attractively located in the center of Naha, and
# has free bikes, free WiFi and a restaurant. This 3-star hotel offers a 24-hour
# front desk and luggage storage space.
#
# Well located in Naha, Toyoko Inn Okinawa Naha Asahibashi Ekimae provides a
# buffet breakfast and free WiFi. This 3-star hotel offers a 24-hour front desk.
# Private parking is available on site.
#
# A 7-minute walk from Ishigaki Port Ricoh Ferry Terminal and a 3-minute drive
# from the beach, Hotel Patina Ishigakijima offers cozy rooms with hardwood
# floors, free internet and a private balcony.
#
# Located in Henza, within 1.7 miles of Hamahiga Beach and 3.4 miles of Yakena
# Bus Terminal, Umi no Yado Umikaze provides accommodations with a garden and
# free WiFi as well as free private parking for...
#
# A 15-minute walk from the vibrant Kokusai Dori Street, Libre Garden features a
# garden, an Italian restaurant and free Wi-Fi throughout the property. It
# offers contemporary rooms with a classical...
#
# We have more than 70 million property reviews, all from real, verified guests.
#
# How does it work?
#
# 1
#
# It starts with a booking
#
# It starts with a booking
#
# The only way to leave a review is to first make a booking. That's how we know
# our reviews come from real guests who have stayed at the property.
#
# 2
#
# Followed by a trip
#
# Followed by a trip
#
# When guests stay at the property, they check out how quiet the room is, how
# friendly the staff is, and more.
#
# 3
#
# And finally, a review
#
# And finally, a review
#
# After their trip, guests tell us about their stay. We check for naughty words
# and verify the authenticity of all guest reviews before adding them to our
# site.
#
# If you booked through us and want to leave a review, please sign in first.
#
#
#
# INFO     [agent]
# 📍 Step 27
# INFO     [agent] ⚠ Eval: Failed - Still could not find the cheapest hotel in Okinawa for the given dates.
# INFO     [agent] 🧠 Memory: Multiple tab switches and price reveals were attempted without successful extraction and listing analysis completion.
# INFO     [agent] 🎯 Next goal: Reapproach initial search and ensure proper direction selection or scroll necessary until clearer interface manifest.
# INFO     [agent] 🛠️  Action 1/6: {"switch_tab":{"page_id":0}}
# INFO     [agent] 🛠️  Action 2/6: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/6: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 4/6: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 5/6: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 6/6: {"extract_content":{"include_links":true}}
# INFO     [controller] 🔄  Switched to tab 0
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [controller] 🔍  Scrolled down the page by one page
# INFO     [agent]
# 📍 Step 28
# INFO     [agent] 👍 Eval: Success - Clicked 'Show prices' allowing price reveal.
# INFO     [agent] 🧠 Memory: Engaged significant interfaces, involving through settings and deductions based prices in current options.
# INFO     [agent] 🎯 Next goal: Identify clicked buttons should have opened price dialogue or continued visibility and start concluding.
# INFO     [agent] 🛠️  Action 1/3: {"click_element":{"index":44}}
# INFO     [agent] 🛠️  Action 2/3: {"scroll_down":{}}
# INFO     [agent] 🛠️  Action 3/3: {"extract_content":{"include_links":true}}
# ERROR    [browser] Failed to update state: Page.evaluate: Target page, context or browser has been closed
# ERROR    [browser] Failed to locate element: Page.query_selector: Target page, context or browser has been closed
# WARNING  [controller] Element not clickable with index 44 - most likely the page changed
# INFO     [agent]
# 📍 Step 29
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Browser closed: no valid pages available
# INFO     [agent]
# 📍 Step 29
# ERROR    [agent] ❌ Result failed 2/3 times:
#  Browser closed: no valid pages available
# INFO     [agent]
# 📍 Step 29

# %% [markdown]
# > Note: The current implementation of the agent has a limitation where it cannot properly set the date range on booking.com. Instead of setting the specified dates (2025-08-01 to 2025-08-03), the agent continuously scrolls and clicks into individual hotels without first setting the date range. As a result, the website does not display any pricing information since no dates are selected, making it impossible for the agent to find and compare hotel prices.

# %%
# Let's make it easier
task = "Go to price.com.hk to find the Nvidia RTX 4090 latest price"

agent = Agent(
    task=task, # Task description
    llm=openai # Language model
)

result = await agent.run()
print(result)
# Out:
# INFO     [agent] 🚀 Starting task: Go to price.com.hk to find the Nvidia RTX 4090 latest price
# INFO     [agent]
# 📍 Step 1
# INFO     [agent] ⚠ Eval: Failed - I am currently on a blank page which does not provide any information about the Nvidia RTX 4090 price.
# INFO     [agent] 🧠 Memory: Start browsing price.com.hk to find Nvidia RTX 4090 latest price.
# INFO     [agent] 🎯 Next goal: Navigate to price.com.hk to search for the Nvidia RTX 4090 price.
# INFO     [agent] 🛠️  Action 1/1: {"go_to_url":{"url":"https://www.price.com.hk"}}
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action go_to_url: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.price.com.hk/", waiting until "load"
#
# INFO     [agent]
# 📍 Step 2
# INFO     [agent] 🤷 Eval: Unknown - Page loaded successfully with interactive options.
# INFO     [agent] 🧠 Memory: Plan to search for Nvidia RTX 4090 on the price.com.hk page using the search box.
# INFO     [agent] 🎯 Next goal: Dismiss any cookies messages, input the Nvidia RTX 4090 in the search bar, and execute the search.
# INFO     [agent] 🛠️  Action 1/3: {"click_element":{"index":3}}
# INFO     [agent] 🛠️  Action 2/3: {"input_text":{"index":19,"text":"Nvidia RTX 4090"}}
# INFO     [agent] 🛠️  Action 3/3: {"click_element":{"index":20}}
# WARNING  [controller] Element not clickable with index 3 - most likely the page changed
# INFO     [agent]
# 📍 Step 3
# INFO     [agent] ⚠ Eval: Failed - Cookie message dismissal timed out and search execution was not started.
# INFO     [agent] 🧠 Memory: Plan to search for Nvidia RTX 4090 on the price.com.hk page using the search box.
# INFO     [agent] 🎯 Next goal: Input the 'Nvidia RTX 4090' into the search box and initiate the search to find the GPU's price.
# INFO     [agent] 🛠️  Action 1/2: {"input_text":{"index":15,"text":"Nvidia RTX 4090"}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element":{"index":16}}
# ERROR    [agent] ❌ Result failed 1/3 times:
#  Error executing action input_text: Failed to input text into element: <input id="searchq" maxlength="200" name="q" type="text" class="form-control" placeholder="搜索 產品 / 品牌 / 商戶" autocomplete="off" style=""> [interactive, top, highlight:15]. Error: Timeout 30000ms exceeded.
# INFO     [agent]
# 📍 Step 4
# INFO     [agent] ⚠ Eval: Failed - Previous input attempt timed out.
# INFO     [agent] 🧠 Memory: Previous attempts to input 'Nvidia RTX 4090' in the search box failed. Focus on ensuring text input and search execution.
# INFO     [agent] 🎯 Next goal: Retry entering 'Nvidia RTX 4090' into the search box and initiating the search by clicking the search button.
# INFO     [agent] 🛠️  Action 1/2: {"input_text":{"index":15,"text":"Nvidia RTX 4090"}}
# INFO     [agent] 🛠️  Action 2/2: {"click_element":{"index":16}}
# ERROR    [agent] ❌ Result failed 2/3 times:
#  Error executing action input_text: Failed to input text into element: <input id="searchq" maxlength="200" name="q" type="text" class="form-control" placeholder="搜索 產品 / 品牌 / 商戶" autocomplete="off" style=""> [interactive, top, highlight:15]. Error: Timeout 30000ms exceeded.
# INFO     [agent]
# 📍 Step 5
# INFO     [agent] ⚠ Eval: Failed - Previous input attempts timed out, possibly due to search box technical issues or site performance problems.
# INFO     [agent] 🧠 Memory: Previous attempts to input 'Nvidia RTX 4090' in the search box failed. Look through available categories for graphics cards.
# INFO     [agent] 🎯 Next goal: Explore the available categories or elements that may redirect to a graphics card section to find Nvidia RTX 4090.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":43}}
# INFO     [controller] 🖱️  Clicked button with index 43: 電腦
# INFO     [agent]
# 📍 Step 6
# INFO     [agent] 👍 Eval: Success - Successfully navigated to the '電腦' section and can now proceed towards graphics cards.
# INFO     [agent] 🧠 Memory: In the computer section, proceed to locate the '顯示卡' (graphics card) section to find Nvidia RTX 4090 pricing.
# INFO     [agent] 🎯 Next goal: Proceed to the '顯示卡' section to find Nvidia RTX 4090 pricing.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":51}}
# INFO     [controller] 🖱️  Clicked button with index 51: 顯示卡
# INFO     [agent]
# 📍 Step 7
# INFO     [agent] 👍 Eval: Success - Reached the graphics card category section where specific graphics cards can be found.
# INFO     [agent] 🧠 Memory: Locate Nvidia RTX 4090 within the graphics card section to determine its current price.
# INFO     [agent] 🎯 Next goal: Search within the graphics card section for Nvidia RTX 4090 to find its pricing information.
# INFO     [agent] 🛠️  Action 1/2: {"scroll_to_text":{"text":"RTX 4090"}}
# INFO     [agent] 🛠️  Action 2/2: {"extract_content":{"include_links":false}}
# INFO     [controller] Text 'RTX 4090' not found or not visible on page
# INFO     [controller] 📄  Extracted page as text
# : 無線/有線:無線Wi-Fi 制式:Wi-Fi 7 (802.11be)傳輸速度:688+5764MbpsWi-Fi 速度規格:BE6500四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是GigaBit LAN:是WAN位數量:1LAN位數量:3USB插位數目:1外置天線/內置天線:外置天線無線/有線:無線Wi-Fi 制式:Wi-Fi 7 (802.11be)傳輸速度:688 + 2882MbpsWi-Fi 速度規格:BE3600四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是WAN位數量:1LAN位數量:4USB插位數目:1外置天線/內置天線:外置天線屏幕尺寸:16吋解像度:3072 x 1920螢幕刷新率:60Hz對比度:1500:1亮度:400cd/㎡反應時間:10ms介面:HDMI, USB-C晶片組:AMD B850Socket:AM5支援記憶體:DDR5外型規格:ATX尺寸:30.5 x 24.4cmIP Cam/Webcam:IP Cam無線/有線:無線解像度:2960 x 1666連接介面:WiFi, BT 5.2尺寸:78 x 78 x 124mm重量:301g上市日期:2024年10月作業系統:Windows 11 Home處理器:Intel Core 5-120U (Intel Core 5 - Series 1)面板/背光:IPS顯示屏:14吋解像度:1920 x 1080螢幕刷新率:60Hz記憶體:16GB硬碟:512GB硬碟類型:SSD顯示卡:Integrated Intel Graphics重量:1.37kg尺寸:324.3 x 213.8 x 17.9mm功能:鏡頭遮蓋無線/有線:無線Wi-Fi 制式:Wi-Fi 6 (802.11ax)傳輸速度:300 + 1201MbpsWi-Fi 速度規格:AX1500四頻/三頻/雙頻/單頻:雙頻GigaBit LAN:是WAN位數量:1LAN位數量:3外置天線/內置天線:外置天線無線/有線:無線Wi-Fi 制式:Wi-Fi 6 (802.11ax)傳輸速度:574 + 4804MbpsWi-Fi 速度規格:AX5400四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是GigaBit LAN:是WAN位數量:1LAN位數量:4USB插位數目:1外置天線/內置天線:外置天線面板/背光:IPS屏幕尺寸:65吋解像度:3840 x 2160產品特點:內置喇叭對比度:1200:1亮度:440cd/㎡反應時間:8ms介面:HDMI x 4可視角度 (水平):178°可視角度 (垂直):178°上市日期:2024年10月面板/背光:IPS屏幕尺寸:24.5吋解像度:1920 x 1080螢幕刷新率:120Hz產品特點:內置喇叭對比度:1500:1亮度:300cd/㎡反應時間:1ms介面:HDMI 2.0 (FHD@120Hz) x 1, DisplayPort (1.4a) x 1, D-Sub (VGA) x 1, Headphone-out, Line-In可視角度 (水平):178°可視角度 (垂直):178°聲道:2.0有線/無線:無線頻率:100Hz-20kHz輸入功率:12W尺寸:410 x 92.7 x 73.7mm重量:1.037kg類型:電競遊戲喇叭IP Cam/Webcam:IP Cam無線/有線:無線解像度:2560 x 1440鏡頭移動角度:水平移動: 360°, 垂直移動: 149°連接介面:WiFi尺寸:80 x 80 x 112mm有線/無線:有線頻率:80Hz-20kHz輸入介面:藍牙 5.3, 光纖輸入, USB 音訊, USB 電源（USB-C，最低 5V 2A), PD 電源適配器 (最低 30W), 3.5mm AUX 輸入, 耳機/耳麥埠尺寸:左喇叭：約 123 x 123 x 118mm, 右喇叭：約 123 x 123 x 118mm重量:左喇叭：0.365kg, 右喇叭：0.415kg聲道:2.0有線/無線:有線頻率:65Hz-20kHz輸入功率:60W靈敏度:85dB尺寸:510 x 102.7 x 82.6mm重量:1.5kg類型:電競遊戲喇叭組合/鍵盤:鍵盤無線/有線:無線連接埠:USB, 藍牙
#
# INFO     [agent]
# 📍 Step 8
# INFO     [agent] ⚠ Eval: Failed - Text 'RTX 4090' was not found on the current visible section of the page.
# INFO     [agent] 🧠 Memory: Attempt to locate Nvidia RTX 4090 through scroll and visual verification, as the text was not found immediately.
# INFO     [agent] 🎯 Next goal: Scroll down the page to find the Nvidia RTX 4090 graphics card.
# INFO     [agent] 🛠️  Action 1/1: {"scroll_down":{"amount":5000}}
# INFO     [controller] 🔍  Scrolled down the page by 5000 pixels
# INFO     [agent]
# 📍 Step 9
# INFO     [agent] ⚠ Eval: Failed - Nvidia RTX 4090 still not found after scrolling the page significantly.
# INFO     [agent] 🧠 Memory: Attempted to locate Nvidia RTX 4090 through additional scrolling without success. Explore further for targeted information related to Nvidia RTX 4090.
# INFO     [agent] 🎯 Next goal: Explore further by using the page content extraction to search for Nvidia RTX 4090 keywords.
# INFO     [agent] 🛠️  Action 1/1: {"extract_content":{"include_links":true}}
# INFO     [controller] 📄  Extracted page as markdown
# : 無線/有線: | 無線
# ---|---
# Wi-Fi 制式: | Wi-Fi 7 (802.11be)
# 傳輸速度: | 688+5764Mbps
# Wi-Fi 速度規格: | BE6500
# 四頻/三頻/雙頻/單頻: | 雙頻
# Mesh Wi-Fi: | 是
# GigaBit LAN: | 是
# ---|---
# WAN位數量: | 1
# ---|---
# LAN位數量: | 3
# ---|---
# USB插位數目: | 1
# ---|---
# 外置天線/內置天線: | 外置天線
# ---|---
# 無線/有線: | 無線
# ---|---
# Wi-Fi 制式: | Wi-Fi 7 (802.11be)
# 傳輸速度: | 688 + 2882Mbps
# Wi-Fi 速度規格: | BE3600
# 四頻/三頻/雙頻/單頻: | 雙頻
# Mesh Wi-Fi: | 是
# ---|---
# WAN位數量: | 1
# ---|---
# LAN位數量: | 4
# ---|---
# USB插位數目: | 1
# ---|---
# 外置天線/內置天線: | 外置天線
# ---|---
# 屏幕尺寸: | 16吋
# ---|---
# 解像度: | 3072 x 1920
# 螢幕刷新率: | 60Hz
# 對比度: | 1500:1
# 亮度: | 400cd/㎡
# ---|---
# 反應時間: | 10ms
# ---|---
# 介面: | HDMI, USB-C
# ---|---
# 晶片組: | AMD B850
# ---|---
# Socket: | AM5
# 支援記憶體: | DDR5
# 外型規格: | ATX
# ---|---
# 尺寸: | 30.5 x 24.4cm
# ---|---
# IP Cam/Webcam: | IP Cam
# ---|---
# 無線/有線: | 無線
# 解像度: | 2960 x 1666
# 連接介面: | WiFi, BT 5.2
# ---|---
# 尺寸: | 78 x 78 x 124mm
# ---|---
# 重量: | 301g
# ---|---
# 上市日期: | 2024年10月
# ---|---
# 作業系統: | Windows 11 Home
# ---|---
# 處理器: | Intel Core 5-120U (Intel Core 5 - Series 1)
# 面板/背光: | IPS
# 顯示屏: | 14吋
# 解像度: | 1920 x 1080
# 螢幕刷新率: | 60Hz
# 記憶體: | 16GB
# 硬碟: | 512GB
# ---|---
# 硬碟類型: | SSD
# ---|---
# 顯示卡: | Integrated Intel Graphics
# ---|---
# 重量: | 1.37kg
# ---|---
# 尺寸: | 324.3 x 213.8 x 17.9mm
# ---|---
# 功能: | 鏡頭遮蓋
# ---|---
# 無線/有線: | 無線
# ---|---
# Wi-Fi 制式: | Wi-Fi 6 (802.11ax)
# 傳輸速度: | 300 + 1201Mbps
# Wi-Fi 速度規格: | AX1500
# 四頻/三頻/雙頻/單頻: | 雙頻
# GigaBit LAN: | 是
# ---|---
# WAN位數量: | 1
# ---|---
# LAN位數量: | 3
# ---|---
# 外置天線/內置天線: | 外置天線
# ---|---
# 無線/有線: | 無線
# ---|---
# Wi-Fi 制式: | Wi-Fi 6 (802.11ax)
# 傳輸速度: | 574 + 4804Mbps
# Wi-Fi 速度規格: | AX5400
# 四頻/三頻/雙頻/單頻: | 雙頻
# Mesh Wi-Fi: | 是
# GigaBit LAN: | 是
# ---|---
# WAN位數量: | 1
# ---|---
# LAN位數量: | 4
# ---|---
# USB插位數目: | 1
# ---|---
# 外置天線/內置天線: | 外置天線
# ---|---
# 面板/背光: | IPS
# ---|---
# 屏幕尺寸: | 65吋
# 解像度: | 3840 x 2160
# 產品特點: | 內置喇叭
# 對比度: | 1200:1
# 亮度: | 440cd/㎡
# ---|---
# 反應時間: | 8ms
# ---|---
# 介面: | HDMI x 4
# ---|---
# 可視角度 (水平): | 178°
# ---|---
# 可視角度 (垂直): | 178°
# ---|---
# 上市日期: | 2024年10月
# ---|---
# 面板/背光: | IPS
# ---|---
# 屏幕尺寸: | 24.5吋
# 解像度: | 1920 x 1080
# 螢幕刷新率: | 120Hz
# 產品特點: | 內置喇叭
# 對比度: | 1500:1
# 亮度: | 300cd/㎡
# ---|---
# 反應時間: | 1ms
# ---|---
# 介面: | HDMI 2.0 (FHD@120Hz) x 1, DisplayPort (1.4a) x 1, D-Sub (VGA) x 1, Headphone-out, Line-In
# ---|---
# 可視角度 (水平): | 178°
# ---|---
# 可視角度 (垂直): | 178°
# ---|---
# 聲道: | 2.0
# ---|---
# 有線/無線: | 無線
# 頻率: | 100Hz-20kHz
# 輸入功率: | 12W
# 尺寸: | 410 x 92.7 x 73.7mm
# ---|---
# 重量: | 1.037kg
# ---|---
# 類型: | 電競遊戲喇叭
# ---|---
# IP Cam/Webcam: | IP Cam
# ---|---
# 無線/有線: | 無線
# 解像度: | 2560 x 1440
# 鏡頭移動角度: | 水平移動: 360°, 垂直移動: 149°
# ---|---
# 連接介面: | WiFi
# ---|---
# 尺寸: | 80 x 80 x 112mm
# ---|---
# 有線/無線: | 有線
# ---|---
# 頻率: | 80Hz-20kHz
# 輸入介面: | 藍牙 5.3, 光纖輸入, USB 音訊, USB 電源（USB-C，最低 5V 2A), PD 電源適配器 (最低 30W), 3.5mm AUX 輸入, 耳機/耳麥埠
# 尺寸: | 左喇叭：約 123 x 123 x 118mm, 右喇叭：約 123 x 123 x 118mm
# ---|---
# 重量: | 左喇叭：0.365kg, 右喇叭：0.415kg
# ---|---
# 聲道: | 2.0
# ---|---
# 有線/無線: | 有線
# 頻率: | 65Hz-20kHz
# 輸入功率: | 60W
# 靈敏度: | 85dB
# ---|---
# 尺寸: | 510 x 102.7 x 82.6mm
# ---|---
# 重量: | 1.5kg
# ---|---
# 類型: | 電競遊戲喇叭
# ---|---
# 組合/鍵盤: | 鍵盤
# ---|---
# 無線/有線: | 無線
# 連接埠: | USB, 藍牙
# ---|---
#
#
#
# INFO     [agent]
# 📍 Step 10
# INFO     [agent] ⚠ Eval: Failed - Attempting to extract RTX 4090 but mainly displaying internet specs and other unrelated products.
# INFO     [agent] 🧠 Memory: Attempted extraction did not provide Nvidia RTX 4090 information, investigate directly or search with relevant keywords.
# INFO     [agent] 🎯 Next goal: Close the popup and retry scrolling or searching for Nvidia RTX 4090 details.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":7}}
# INFO     [controller] 🖱️  Clicked button with index 7:
# INFO     [agent]
# 📍 Step 11
# INFO     [agent] ⚠ Eval: Failed - After verifying the visual context, still could not determine where the Nvidia RTX 4090 details are mentioned.
# INFO     [agent] 🧠 Memory: Attempted to locate Nvidia RTX 4090 but was interrupted by an advertisement popup.
# INFO     [agent] 🎯 Next goal: Close the popup using the close button and continue searching or scrolling to find Nvidia RTX 4090.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":2}}
# INFO     [controller] 🖱️  Clicked button with index 2:
# INFO     [agent]
# 📍 Step 12
# INFO     [agent] ⚠ Eval: Failed - The Nvidia RTX 4090 information is not readily visible, and the page is covered by an advertisement popup.
# INFO     [agent] 🧠 Memory: Effort to locate Nvidia RTX 4090 has been interrupted by repeated advertisement pop-ups.
# INFO     [agent] 🎯 Next goal: Dismiss the current advertisement popup and attempt a further scroll to locate the Nvidia RTX 4090 info.
# INFO     [agent] 🛠️  Action 1/1: {"click_element":{"index":219}}
# INFO     [controller] 🖱️  Clicked button with index 219:
# INFO     [agent]
# 📍 Step 13
# INFO     [agent] ⚠ Eval: Failed - Total lack of success in retrieving Nvidia RTX 4090 pricing despite navigating and scrolling through relevant sections.
# INFO     [agent] 🧠 Memory: The search for Nvidia RTX 4090 prices has been hampered by page layout, advertisements, and interface constraints.
# INFO     [agent] 🎯 Next goal: Attempt the task by searching Nvidia RTX 4090 on the global search engine if site navigation continues to fail.
# INFO     [agent] 🛠️  Action 1/1: {"search_google":{"query":"Nvidia RTX 4090 latest price site:price.com.hk"}}
# INFO     [controller] 🔍  Searched for "Nvidia RTX 4090 latest price site:price.com.hk" in Google
# INFO     [agent]
# 📍 Step 14
# INFO     [agent] 👍 Eval: Success - Found the latest prices for Nvidia RTX 4090 models listed on price.com.hk through Google search results.
# INFO     [agent] 🧠 Memory: Successfully retrieved pricing details for various Nvidia RTX 4090 models on price.com.hk through a Google search.
# INFO     [agent] 🎯 Next goal: Conclude the task by summarizing the retrieved Nvidia RTX 4090 pricing information.
# INFO     [agent] 🛠️  Action 1/1: {"done":{"text":"The latest prices for Nvidia RTX 4090 on price.com.hk are: \n- Nvidia GeForce RTX 4090 Founders Edition: HK$18,000\n- Zotac GAMING GeForce RTX 4090 Trinity: HK$16,000-16,390\n- MSI GeForce RTX 4090 SUPRIM 24G: HK$18,900\n- Gigabyte GeForce RTX 4090 GAMING OC 24G: HK$16,900-19,000\n- MSI GeForce RTX 4090 VENTUS 3X 24G OC: HK$16,200-19,500\n- ASUS TUF Gaming GeForce RTX 4090 OC Edition 24GB: HK$18,500-21,588"}}
# INFO     [agent] 📄 Result: The latest prices for Nvidia RTX 4090 on price.com.hk are:
# - Nvidia GeForce RTX 4090 Founders Edition: HK$18,000
# - Zotac GAMING GeForce RTX 4090 Trinity: HK$16,000-16,390
# - MSI GeForce RTX 4090 SUPRIM 24G: HK$18,900
# - Gigabyte GeForce RTX 4090 GAMING OC 24G: HK$16,900-19,000
# - MSI GeForce RTX 4090 VENTUS 3X 24G OC: HK$16,200-19,500
# - ASUS TUF Gaming GeForce RTX 4090 OC Edition 24GB: HK$18,500-21,588
# INFO     [agent] ✅ Task completed successfully
# INFO     [agent] Created GIF at agent_history.gif
# AgentHistoryList(all_results=[ActionResult(is_done=False, extracted_content=None, error='Error executing action go_to_url: Page.goto: Timeout 30000ms exceeded.\nCall log:\n  - navigating to "https://www.price.com.hk/", waiting until "load"\n', include_in_memory=True), ActionResult(is_done=False, extracted_content=None, error='Failed to click element: <a aria-label="dismiss cookie message" role="button" tabindex="0" class="cc-btn cc-dismiss"> [interactive, top, highlight:3]. Error: Failed to click element: Timeout 30000ms exceeded.', include_in_memory=False), ActionResult(is_done=False, extracted_content=None, error='Error executing action input_text: Failed to input text into element: <input id="searchq" maxlength="200" name="q" type="text" class="form-control" placeholder="搜索 產品 / 品牌 / 商戶" autocomplete="off" style=""> [interactive, top, highlight:15]. Error: Timeout 30000ms exceeded.', include_in_memory=True), ActionResult(is_done=False, extracted_content=None, error='Error executing action input_text: Failed to input text into element: <input id="searchq" maxlength="200" name="q" type="text" class="form-control" placeholder="搜索 產品 / 品牌 / 商戶" autocomplete="off" style=""> [interactive, top, highlight:15]. Error: Timeout 30000ms exceeded.', include_in_memory=True), ActionResult(is_done=False, extracted_content='🖱️  Clicked button with index 43: 電腦', error=None, include_in_memory=True), ActionResult(is_done=False, extracted_content='🖱️  Clicked button with index 51: 顯示卡', error=None, include_in_memory=True), ActionResult(is_done=False, extracted_content="Text 'RTX 4090' not found or not visible on page", error=None, include_in_memory=True), ActionResult(is_done=False, extracted_content='📄  Extracted page as text\n: 無線/有線:無線Wi-Fi 制式:Wi-Fi 7 (802.11be)傳輸速度:688+5764MbpsWi-Fi 速度規格:BE6500四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是GigaBit LAN:是WAN位數量:1LAN位數量:3USB插位數目:1外置天線/內置天線:外置天線無線/有線:無線Wi-Fi 制式:Wi-Fi 7 (802.11be)傳輸速度:688 + 2882MbpsWi-Fi 速度規格:BE3600四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是WAN位數量:1LAN位數量:4USB插位數目:1外置天線/內置天線:外置天線屏幕尺寸:16吋解像度:3072 x 1920螢幕刷新率:60Hz對比度:1500:1亮度:400cd/㎡反應時間:10ms介面:HDMI, USB-C晶片組:AMD B850Socket:AM5支援記憶體:DDR5外型規格:ATX尺寸:30.5 x 24.4cmIP Cam/Webcam:IP Cam無線/有線:無線解像度:2960 x 1666連接介面:WiFi, BT 5.2尺寸:78 x 78 x 124mm重量:301g上市日期:2024年10月作業系統:Windows 11 Home處理器:Intel Core 5-120U (Intel Core 5 - Series 1)面板/背光:IPS顯示屏:14吋解像度:1920 x 1080螢幕刷新率:60Hz記憶體:16GB硬碟:512GB硬碟類型:SSD顯示卡:Integrated Intel Graphics重量:1.37kg尺寸:324.3 x 213.8 x 17.9mm功能:鏡頭遮蓋無線/有線:無線Wi-Fi 制式:Wi-Fi 6 (802.11ax)傳輸速度:300 + 1201MbpsWi-Fi 速度規格:AX1500四頻/三頻/雙頻/單頻:雙頻GigaBit LAN:是WAN位數量:1LAN位數量:3外置天線/內置天線:外置天線無線/有線:無線Wi-Fi 制式:Wi-Fi 6 (802.11ax)傳輸速度:574 + 4804MbpsWi-Fi 速度規格:AX5400四頻/三頻/雙頻/單頻:雙頻Mesh Wi-Fi:是GigaBit LAN:是WAN位數量:1LAN位數量:4USB插位數目:1外置天線/內置天線:外置天線面板/背光:IPS屏幕尺寸:65吋解像度:3840 x 2160產品特點:內置喇叭對比度:1200:1亮度:440cd/㎡反應時間:8ms介面:HDMI x 4可視角度 (水平):178°可視角度 (垂直):178°上市日期:2024年10月面板/背光:IPS屏幕尺寸:24.5吋解像度:1920 x 1080螢幕刷新率:120Hz產品特點:內置喇叭對比度:1500:1亮度:300cd/㎡反應時間:1ms介面:HDMI 2.0 (FHD@120Hz) x 1, DisplayPort (1.4a) x 1, D-Sub (VGA) x 1, Headphone-out, Line-In可視角度 (水平):178°可視角度 (垂直):178°聲道:2.0有線/無線:無線頻率:100Hz-20kHz輸入功率:12W尺寸:410 x 92.7 x 73.7mm重量:1.037kg類型:電競遊戲喇叭IP Cam/Webcam:IP Cam無線/有線:無線解像度:2560 x 1440鏡頭移動角度:水平移動: 360°, 垂直移動: 149°連接介面:WiFi尺寸:80 x 80 x 112mm有線/無線:有線頻率:80Hz-20kHz輸入介面:藍牙 5.3, 光纖輸入, USB 音訊, USB 電源（USB-C，最低 5V 2A), PD 電源適配器 (最低 30W), 3.5mm AUX 輸入, 耳機/耳麥埠尺寸:左喇叭：約 123 x 123 x 118mm, 右喇叭：約 123 x 123 x 118mm重量:左喇叭：0.365kg, 右喇叭：0.415kg聲道:2.0有線/無線:有線頻率:65Hz-20kHz輸入功率:60W靈敏度:85dB尺寸:510 x 102.7 x 82.6mm重量:1.5kg類型:電競遊戲喇叭組合/鍵盤:鍵盤無線/有線:無線連接埠:USB, 藍牙\n', error=None, include_in_memory=False), ActionResult(is_done=False, extracted_content='🔍  Scrolled down the page by 5000 pixels', error=None, include_in_memory=True), ActionResult(is_done=False, extracted_content='📄  Extracted page as markdown\n: 無線/有線: | 無線  \n---|---  \nWi-Fi 制式: | Wi-Fi 7 (802.11be)  \n傳輸速度: | 688+5764Mbps  \nWi-Fi 速度規格: | BE6500  \n四頻/三頻/雙頻/單頻: | 雙頻  \nMesh Wi-Fi: | 是  \nGigaBit LAN: | 是  \n---|---  \nWAN位數量: | 1  \n---|---  \nLAN位數量: | 3  ...

# %% [markdown]
# # Results and Observations
#
# When attempting to scrape price.com.hk, the agent encountered several challenges:
# 1. The website seemed to be stuck in an infinite loading state, causing the agent to wait indefinitely
# 2. An advertisement popup appeared and blocked the screen, preventing the agent from accessing the main content
# 3. Interestingly, after failing to interact with price.com.hk, the agent attempted to fall back to Google search to find the information instead
#
# ![Screenshot 2](../../../data/screenshots/browser-use/screenshot-2.png)
#
# Screenshot 2 show the advertisement popup blocked the screen
#
# ![Screenshot 3](../../../data/screenshots/browser-use/screenshot-3.png)
#
# Screenshot 3 show the agent go to Google and search the result
#
# This demonstrates some common challenges in web scraping, such as dealing with slow-loading pages, handling popup advertisements, and the agent's attempt to find alternative data sources when the primary source is inaccessible.
