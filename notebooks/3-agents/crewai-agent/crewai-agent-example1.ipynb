# %%
# %pip install crewai 'crewai[tools]' setuptools
# Out:
# Collecting crewai
#   Using cached crewai-0.105.0-py3-none-any.whl.metadata (28 kB)
# Collecting setuptools
#   Using cached setuptools-76.0.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai)
#   Using cached auth0_python-4.8.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting blinker>=1.9.0 (from crewai)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting chromadb>=0.5.23 (from crewai)
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting click>=8.1.7 (from crewai)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting instructor>=1.3.3 (from crewai)
#   Using cached instructor-1.7.3-py3-none-any.whl.metadata (19 kB)
# Collecting json-repair>=0.25.2 (from crewai)
#   Using cached json_repair-0.39.1-py3-none-any.whl.metadata (11 kB)
# Collecting json5>=0.10.0 (from crewai)
#   Using cached json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.60.2 (from crewai)
#   Using cached litellm-1.60.2-py3-none-any.whl.metadata (36 kB)
# Collecting openai>=1.13.3 (from crewai)
#   Downloading openai-1.66.2-py3-none-any.whl.metadata (25 kB)
# Collecting openpyxl>=3.1.5 (from crewai)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-api>=1.22.0 (from crewai)
#   Using cached opentelemetry_api-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.22.0 (from crewai)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.22.0 (from crewai)
#   Using cached opentelemetry_sdk-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Using cached pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
# Collecting pydantic>=2.4.2 (from crewai)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting python-dotenv>=1.0.0 (from crewai)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pyvis>=0.3.2 (from crewai)
#   Using cached pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting regex>=2024.9.11 (from crewai)
#   Using cached regex-2024.11.6-cp312-cp312-macosx_10_13_x86_64.whl.metadata (40 kB)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Using cached tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Using cached tomli-2.2.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Using cached uv-0.6.6-py3-none-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting aiohttp (from litellm==1.60.2->crewai)
#   Downloading aiohttp-3.11.13-cp312-cp312-macosx_10_13_x86_64.whl.metadata (7.7 kB)
# Collecting httpx<0.28.0,>=0.23.0 (from litellm==1.60.2->crewai)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.60.2->crewai)
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting jinja2<4.0.0,>=3.1.2 (from litellm==1.60.2->crewai)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting jsonschema<5.0.0,>=4.22.0 (from litellm==1.60.2->crewai)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting tiktoken>=0.7.0 (from litellm==1.60.2->crewai)
#   Downloading tiktoken-0.9.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.7 kB)
# Collecting tokenizers (from litellm==1.60.2->crewai)
#   Using cached tokenizers-0.21.0-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# Collecting crewai-tools>=0.37.0 (from crewai[tools])
#   Using cached crewai_tools-0.37.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting cryptography>=43.0.1 (from auth0-python>=4.7.1->crewai)
#   Downloading cryptography-44.0.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting pyjwt>=2.8.0 (from auth0-python>=4.7.1->crewai)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting requests>=2.32.3 (from auth0-python>=4.7.1->crewai)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting urllib3>=2.2.3 (from auth0-python>=4.7.1->crewai)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting build>=1.0.3 (from chromadb>=0.5.23->crewai)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.23->crewai)
#   Using cached chroma_hnswlib-0.7.6-cp312-cp312-macosx_10_9_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.23->crewai)
#   Using cached fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting numpy>=1.22.5 (from chromadb>=0.5.23->crewai)
#   Downloading numpy-2.2.3-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Using cached posthog-3.19.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting typing_extensions>=4.5.0 (from chromadb>=0.5.23->crewai)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.23->crewai)
#   Using cached onnxruntime-1.21.0-cp312-cp312-macosx_13_0_universal2.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.23->crewai)
#   Using cached opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai)
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# Collecting tqdm>=4.65.0 (from chromadb>=0.5.23->crewai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb>=0.5.23->crewai)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb>=0.5.23->crewai)
#   Using cached grpcio-1.71.0-cp312-cp312-macosx_10_14_universal2.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Using cached bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb>=0.5.23->crewai)
#   Using cached typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai)
#   Using cached kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tenacity>=8.2.3 (from chromadb>=0.5.23->crewai)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting PyYAML>=6.0.0 (from chromadb>=0.5.23->crewai)
#   Using cached PyYAML-6.0.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Using cached mmh3-5.1.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (16 kB)
# Collecting orjson>=3.9.12 (from chromadb>=0.5.23->crewai)
#   Using cached orjson-3.10.15-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting rich>=10.11.0 (from chromadb>=0.5.23->crewai)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting docker>=7.1.0 (from crewai-tools>=0.37.0->crewai[tools])
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting embedchain>=0.1.114 (from crewai-tools>=0.37.0->crewai[tools])
#   Using cached embedchain-0.1.127-py3-none-any.whl.metadata (9.3 kB)
# Collecting lancedb>=0.5.4 (from crewai-tools>=0.37.0->crewai[tools])
#   Using cached lancedb-0.21.1-cp39-abi3-macosx_10_15_x86_64.whl.metadata (4.1 kB)
# Collecting pyright>=1.1.350 (from crewai-tools>=0.37.0->crewai[tools])
#   Using cached pyright-1.1.396-py3-none-any.whl.metadata (6.6 kB)
# Collecting pytube>=15.0.0 (from crewai-tools>=0.37.0->crewai[tools])
#   Using cached pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting docstring-parser<1.0,>=0.16 (from instructor>=1.3.3->crewai)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting jiter<0.9,>=0.6.1 (from instructor>=1.3.3->crewai)
#   Using cached jiter-0.8.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor>=1.3.3->crewai)
#   Downloading pydantic_core-2.31.1-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.5 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.13.3->crewai)
#   Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.13.3->crewai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from openai>=1.13.3->crewai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting et-xmlfile (from openpyxl>=3.1.5->crewai)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.22.0->crewai)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.60.2->crewai)
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached googleapis_common_protos-1.69.1-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.30.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.30.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached opentelemetry_proto-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.30.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.51b0 (from opentelemetry-sdk>=1.22.0->crewai)
#   Using cached opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber>=0.11.4->crewai)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting Pillow>=9.1 (from pdfplumber>=0.11.4->crewai)
#   Using cached pillow-11.1.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.1 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Using cached pypdfium2-4.30.1-py3-none-macosx_10_13_x86_64.whl.metadata (48 kB)
# Collecting charset-normalizer>=2.0.0 (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.4.2->crewai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor>=1.3.3->crewai)
#   Using cached pydantic_core-2.27.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: ipython>=5.3.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (9.0.2)
# Collecting jsonpickle>=1.4.1 (from pyvis>=0.3.2->crewai)
#   Using cached jsonpickle-4.0.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting networkx>=1.11 (from pyvis>=0.3.2->crewai)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->litellm==1.60.2->crewai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->litellm==1.60.2->crewai)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp->litellm==1.60.2->crewai)
#   Using cached attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->litellm==1.60.2->crewai)
#   Using cached frozenlist-1.5.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->litellm==1.60.2->crewai)
#   Using cached multidict-6.1.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->litellm==1.60.2->crewai)
#   Downloading propcache-0.3.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->litellm==1.60.2->crewai)
#   Using cached yarl-1.18.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (69 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.13.3->crewai)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=19.1 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=0.5.23->crewai)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting cffi>=1.12 (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai)
#   Using cached cffi-1.17.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (1.5 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai)
#   Using cached wrapt-1.17.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.4 kB)
# Collecting alembic<2.0.0,>=1.13.1 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting chromadb>=0.5.23 (from crewai)
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting cohere<6.0,>=5.3 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached cohere-5.14.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting google-cloud-aiplatform<2.0.0,>=1.26.1 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_cloud_aiplatform-1.84.0-py2.py3-none-any.whl.metadata (33 kB)
# Collecting gptcache<0.2.0,>=0.1.43 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached gptcache-0.1.44-py3-none-any.whl.metadata (24 kB)
# Collecting langchain<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain-0.3.20-py3-none-any.whl.metadata (7.7 kB)
# Collecting langchain-cohere<0.4.0,>=0.3.0 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_cohere-0.3.5-py3-none-any.whl.metadata (6.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_community-0.3.19-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-openai<0.3.0,>=0.2.1 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting mem0ai<0.2.0,>=0.1.54 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached mem0ai-0.1.67-py3-none-any.whl.metadata (8.6 kB)
# Collecting pypdf<6.0.0,>=5.0.0 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pypdf-5.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting pysbd<0.4.0,>=0.3.4 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting schema<0.8.0,>=0.7.5 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting sqlalchemy<3.0.0,>=2.0.27 (from embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached sqlalchemy-2.0.39-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.6 kB)
# Collecting tiktoken>=0.7.0 (from litellm==1.60.2->crewai)
#   Using cached tiktoken-0.7.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting tokenizers (from litellm==1.60.2->crewai)
#   Using cached tokenizers-0.20.3-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi>=0.95.2->chromadb>=0.5.23->crewai)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting certifi (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: decorator in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.1)
# Requirement already satisfied: stack_data in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.0 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai)
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai)
#   Downloading rpds_py-0.23.1-cp312-cp312-macosx_10_12_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting deprecation (from lancedb>=0.5.4->crewai-tools>=0.37.0->crewai[tools])
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pyarrow>=14 (from lancedb>=0.5.4->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pyarrow-19.0.1-cp312-cp312-macosx_12_0_x86_64.whl.metadata (3.3 kB)
# Collecting pylance>=0.23.2 (from lancedb>=0.5.4->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pylance-0.24.1-cp39-abi3-macosx_10_15_x86_64.whl.metadata (7.2 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting opentelemetry-instrumentation-asgi==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Using cached opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Using cached opentelemetry_instrumentation-0.51b0-py3-none-any.whl.metadata (6.3 kB)
# Collecting opentelemetry-util-http==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Using cached opentelemetry_util_http-0.51b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting nodeenv>=1.6.0 (from pyright>=1.1.350->crewai-tools>=0.37.0->crewai[tools])
#   Using cached nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb>=0.5.23->crewai)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers->litellm==1.60.2->crewai)
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb>=0.5.23->crewai)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Using cached httptools-0.6.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Using cached uvloop-0.21.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Using cached watchfiles-1.0.4-cp312-cp312-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Using cached websockets-15.0.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting Mako (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached fastavro-1.10.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (5.5 kB)
# Collecting httpx-sse==0.4.0 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached types_requests-2.32.0.20250306-py3-none-any.whl.metadata (2.3 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_cloud_storage-2.19.0-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_cloud_bigquery-3.30.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3 (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_cloud_resource_manager-1.14.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting shapely<3.0.0dev (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached shapely-2.0.7-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Collecting langchain-core<1.0.0,>=0.3.41 (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_core-0.3.44-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-experimental<0.4.0,>=0.3.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting pandas>=1.4.3 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (89 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting psycopg2-binary<3.0.0,>=2.9.10 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached psycopg2_binary-2.9.10-cp312-cp312-macosx_12_0_x86_64.whl.metadata (4.9 kB)
# Collecting pytz<2025.0,>=2024.1 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting qdrant-client<2.0.0,>=1.9.1 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached qdrant_client-1.13.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached greenlet-3.1.1-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/kan/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-cloud-core<3.0.0dev,>=2.4.1 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0dev,>=2.0.0 (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.14.0 (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached grpc_google_iam_v1-0.14.1-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached google_crc32c-1.6.0-cp312-cp312-macosx_12_0_x86_64.whl.metadata (2.3 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.41->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached grpcio_tools-1.71.0-cp312-cp312-macosx_10_14_universal2.whl.metadata (5.3 kB)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.37.0->crewai[tools])
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Using cached crewai-0.105.0-py3-none-any.whl (252 kB)
# Using cached litellm-1.60.2-py3-none-any.whl (6.7 MB)
# Using cached setuptools-76.0.0-py3-none-any.whl (1.2 MB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached auth0_python-4.8.1-py3-none-any.whl (134 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached chroma_hnswlib-0.7.6-cp312-cp312-macosx_10_9_x86_64.whl (197 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached crewai_tools-0.37.0-py3-none-any.whl (548 kB)
# Using cached instructor-1.7.3-py3-none-any.whl (79 kB)
# Using cached json_repair-0.39.1-py3-none-any.whl (20 kB)
# Using cached json5-0.10.0-py3-none-any.whl (34 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading openai-1.66.2-py3-none-any.whl (567 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.3/567.3 kB 9.9 MB/s eta 0:00:00
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached opentelemetry_api-1.30.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.30.0-py3-none-any.whl (55 kB)
# Using cached opentelemetry_sdk-1.30.0-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl (177 kB)
# Using cached pdfplumber-0.11.5-py3-none-any.whl (59 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp312-cp312-macosx_10_12_x86_64.whl (1.9 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Using cached regex-2024.11.6-cp312-cp312-macosx_10_13_x86_64.whl (288 kB)
# Using cached tomli-2.2.1-cp312-cp312-macosx_10_13_x86_64.whl (132 kB)
# Using cached tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Using cached uv-0.6.6-py3-none-macosx_10_12_x86_64.whl (15.6 MB)
# Downloading aiohttp-3.11.13-cp312-cp312-macosx_10_13_x86_64.whl (464 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl (498 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading cryptography-44.0.2-cp39-abi3-macosx_10_9_universal2.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 42.7 MB/s eta 0:00:00
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached embedchain-0.1.127-py3-none-any.whl (211 kB)
# Using cached chromadb-0.5.23-py3-none-any.whl (628 kB)
# Using cached fastapi-0.115.11-py3-none-any.whl (94 kB)
# Using cached googleapis_common_protos-1.69.1-py2.py3-none-any.whl (293 kB)
# Using cached grpcio-1.71.0-cp312-cp312-macosx_10_14_universal2.whl (11.3 MB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached jiter-0.8.2-cp312-cp312-macosx_10_12_x86_64.whl (302 kB)
# Using cached jsonpickle-4.0.2-py3-none-any.whl (46 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
# Using cached lancedb-0.21.1-cp39-abi3-macosx_10_15_x86_64.whl (29.8 MB)
# Using cached mmh3-5.1.0-cp312-cp312-macosx_10_13_x86_64.whl (40 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading numpy-2.2.3-cp312-cp312-macosx_14_0_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 43.4 MB/s eta 0:00:00
# Using cached onnxruntime-1.21.0-cp312-cp312-macosx_13_0_universal2.whl (33.7 MB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.51b0-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_util_http-0.51b0-py3-none-any.whl (7.3 kB)
# Using cached orjson-3.10.15-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (249 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached pillow-11.1.0-cp312-cp312-macosx_10_13_x86_64.whl (3.2 MB)
# Using cached posthog-3.19.1-py2.py3-none-any.whl (77 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached pypdfium2-4.30.1-py3-none-macosx_10_13_x86_64.whl (2.9 MB)
# Using cached pyright-1.1.396-py3-none-any.whl (5.7 MB)
# Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-macosx_10_9_x86_64.whl (183 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached tiktoken-0.7.0-cp312-cp312-macosx_10_9_x86_64.whl (960 kB)
# Using cached tokenizers-0.20.3-cp312-cp312-macosx_10_12_x86_64.whl (2.7 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typer-0.15.2-py3-none-any.whl (45 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached alembic-1.15.1-py3-none-any.whl (231 kB)
# Using cached attrs-25.1.0-py3-none-any.whl (63 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached cffi-1.17.1-cp312-cp312-macosx_10_9_x86_64.whl (183 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl (196 kB)
# Using cached cohere-5.14.0-py3-none-any.whl (253 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-macosx_10_13_x86_64.whl (54 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached google_cloud_aiplatform-1.84.0-py2.py3-none-any.whl (7.3 MB)
# Using cached gptcache-0.1.44-py3-none-any.whl (131 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached httptools-0.6.4-cp312-cp312-macosx_10_13_universal2.whl (200 kB)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached langchain-0.3.20-py3-none-any.whl (1.0 MB)
# Using cached langchain_cohere-0.3.5-py3-none-any.whl (45 kB)
# Using cached langchain_community-0.3.19-py3-none-any.whl (2.5 MB)
# Using cached langchain_openai-0.2.14-py3-none-any.whl (50 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl (14 kB)
# Using cached mem0ai-0.1.67-py3-none-any.whl (106 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached multidict-6.1.0-cp312-cp312-macosx_10_9_x86_64.whl (29 kB)
# Using cached nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading propcache-0.3.0-cp312-cp312-macosx_10_13_x86_64.whl (46 kB)
# Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Using cached pyarrow-19.0.1-cp312-cp312-macosx_12_0_x86_64.whl (32.1 MB)
# Using cached pylance-0.24.1-cp39-abi3-macosx_10_15_x86_64.whl (33.7 MB)
# Using cached pypdf-5.3.1-py3-none-any.whl (302 kB)
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.23.1-cp312-cp312-macosx_10_12_x86_64.whl (364 kB)
# Using cached schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sqlalchemy-2.0.39-cp312-cp312-macosx_10_13_x86_64.whl (2.1 MB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
# Using cached uvloop-0.21.0-cp312-cp312-macosx_10_13_x86_64.whl (821 kB)
# Using cached watchfiles-1.0.4-cp312-cp312-macosx_10_12_x86_64.whl (391 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_10_13_x86_64.whl (173 kB)
# Using cached wrapt-1.17.2-cp312-cp312-macosx_10_13_x86_64.whl (38 kB)
# Using cached yarl-1.18.3-cp312-cp312-macosx_10_13_x86_64.whl (94 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached fastavro-1.10.0-cp312-cp312-macosx_10_13_universal2.whl (1.0 MB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Using cached google_cloud_bigquery-3.30.0-py2.py3-none-any.whl (247 kB)
# Using cached google_cloud_resource_manager-1.14.1-py2.py3-none-any.whl (392 kB)
# Using cached google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
# Using cached greenlet-3.1.1-cp312-cp312-macosx_11_0_universal2.whl (274 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached langchain_core-0.3.44-py3-none-any.whl (415 kB)
# Using cached langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
# Using cached langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached psycopg2_binary-2.9.10-cp312-cp312-macosx_12_0_x86_64.whl (3.0 MB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached qdrant_client-1.13.3-py3-none-any.whl (306 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached shapely-2.0.7-cp312-cp312-macosx_10_13_x86_64.whl (1.5 MB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached types_requests-2.32.0.20250306-py3-none-any.whl (20 kB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Using cached Mako-1.3.9-py3-none-any.whl (78 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Using cached google_crc32c-1.6.0-cp312-cp312-macosx_12_0_x86_64.whl (30 kB)
# Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Using cached grpc_google_iam_v1-0.14.1-py2.py3-none-any.whl (19 kB)
# Using cached grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Using cached grpcio_tools-1.71.0-cp312-cp312-macosx_10_14_universal2.whl (6.0 MB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached h2-4.2.0-py3-none-any.whl (60 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: schema, pytz, pypika, mpmath, monotonic, flatbuffers, durationpy, appdirs, zipp, wrapt, websockets, websocket-client, uvloop, uv, urllib3, tzdata, typing_extensions, tqdm, tomli-w, tomli, tenacity, tabulate, sympy, soupsieve, sniffio, shellingham, setuptools, rpds-py, regex, PyYAML, pytube, python-dotenv, pysbd, pyproject_hooks, pypdfium2, pypdf, pyjwt, pycparser, pyasn1, pyarrow, psycopg2-binary, protobuf, propcache, portalocker, Pillow, overrides, orjson, opentelemetry-util-http, oauthlib, numpy, nodeenv, networkx, mypy-extensions, multidict, mmh3, mdurl, marshmallow, MarkupSafe, jsonref, jsonpointer, jsonpickle, json5, json-repair, jiter, importlib-resources, idna, hyperframe, humanfriendly, httpx-sse, httptools, hpack, h11, grpcio, greenlet, google-crc32c, fsspec, frozenlist, filelock, fastavro, et-xmlfile, docstring-parser, distro, deprecation, click, charset-normalizer, certifi, cachetools, blinker, bcrypt, backoff, attrs, asgiref, annotated-types, aiohappyeyeballs, yarl, uvicorn, typing-inspect, types-requests, sqlalchemy, shapely, rsa, requests, referencing, pyright, pylance, pydantic-core, pyasn1-modules, proto-plus, pandas, opentelemetry-proto, openpyxl, markdown-it-py, Mako, jsonpatch, jinja2, importlib-metadata, httpcore, h2, grpcio-tools, googleapis-common-protos, google-resumable-media, deprecated, coloredlogs, chroma-hnswlib, cffi, build, beautifulsoup4, anyio, aiosignal, watchfiles, tiktoken, starlette, rich, requests-toolbelt, requests-oauthlib, pyvis, pydantic, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, jsonschema-specifications, huggingface-hub, httpx, grpcio-status, gptcache, google-auth, docker, dataclasses-json, cryptography, alembic, aiohttp, typer, tokenizers, pydantic-settings, pdfminer.six, opentelemetry-semantic-conventions, openai, langsmith, lancedb, kubernetes, jsonschema, grpc-google-iam-v1, google-api-core, fastapi, auth0-python, qdrant-client, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, litellm, langchain-core, instructor, google-cloud-core, cohere, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mem0ai, langchain-text-splitters, langchain-openai, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, opentelemetry-instrumentation-fastapi, langchain, google-cloud-aiplatform, langchain-community, chromadb, langchain-experimental, crewai, langchain-cohere, embedchain, crewai-tools
# Successfully installed Mako-1.3.9 MarkupSafe-3.0.2 Pillow-11.1.0 PyYAML-6.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.11.13 aiosignal-1.3.2 alembic-1.15.1 annotated-types-0.7.0 anyio-4.8.0 appdirs-1.4.4 asgiref-3.8.1 attrs-25.1.0 auth0-python-4.8.1 backoff-2.2.1 bcrypt-4.3.0 beautifulsoup4-4.13.3 blinker-1.9.0 build-1.2.2.post1 cachetools-5.5.2 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 chroma-hnswlib-0.7.6 chromadb-0.5.23 click-8.1.8 cohere-5.14.0 coloredlogs-15.0.1 crewai-0.105.0 crewai-tools-0.37.0 cryptography-44.0.2 dataclasses-json-0.6.7 deprecated-1.2.18 deprecation-2.1.0 distro-1.9.0 docker-7.1.0 docstring-parser-0.16 durationpy-0.9 embedchain-0.1.127 et-xmlfile-2.0.0 fastapi-0.115.11 fastavro-1.10.0 filelock-3.17.0 flatbuffers-25.2.10 frozenlist-1.5.0 fsspec-2025.3.0 google-api-core-2.24.2 google-auth-2.38.0 google-cloud-aiplatform-1.84.0 google-cloud-bigquery-3.30.0 google-cloud-core-2.4.3 google-cloud-resource-manager-1.14.1 google-cloud-storage-2.19.0 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.69.1 gptcache-0.1.44 greenlet-3.1.1 grpc-google-iam-v1-0.14.1 grpcio-1.71.0 grpcio-status-1.71.0 grpcio-tools-1.71.0 h11-0.14.0 h2-4.2.0 hpack-4.1.0 httpcore-1.0.7 httptools-0.6.4 httpx-0.27.2 httpx-sse-0.4.0 huggingface-hub-0.29.3 humanfriendly-10.0 hyperframe-6.1.0 idna-3.10 importlib-metadata-8.5.0 importlib-resources-6.5.2 instructor-1.7.3 jinja2-3.1.6 jiter-0.8.2 json-repair-0.39.1 json5-0.10.0 jsonpatch-1.33 jsonpickle-4.0.2 jsonpointer-3.0.0 jsonref-1.1.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 kubernetes-32.0.1 lancedb-0.21.1 langchain-0.3.20 langchain-cohere-0.3.5 langchain-community-0.3.19 langchain-core-0.3.44 langchain-experimental-0.3.4 langchain-openai-0.2.14 langchain-text-splitters-0.3.6 langsmith-0.1.147 litellm-1.60.2 markdown-it-py-3.0.0 marshmallow-3.26.1 mdurl-0.1.2 mem0ai-0.1.67 mmh3-5.1.0 monotonic-1.6 mpmath-1.3.0 multidict-6.1.0 mypy-extensions-1.0.0 networkx-3.4.2 nodeenv-1.9.1 numpy-2.2.3 oauthlib-3.2.2 onnxruntime-1.21.0 openai-1.66.2 openpyxl-3.1.5 opentelemetry-api-1.30.0 opentelemetry-exporter-otlp-proto-common-1.30.0 opentelemetry-exporter-otlp-proto-grpc-1.30.0 opentelemetry-exporter-otlp-proto-http-1.30.0 opentelemetry-instrumentation-0.51b0 opentelemetry-instrumentation-asgi-0.51b0 opentelemetry-instrumentation-fastapi-0.51b0 opentelemetry-proto-1.30.0 opentelemetry-sdk-1.30.0 opentelemetry-semantic-conventions-0.51b0 opentelemetry-util-http-0.51b0 orjson-3.10.15 overrides-7.7.0 pandas-2.2.3 pdfminer.six-20231228 pdfplumber-0.11.5 portalocker-2.10.1 posthog-3.19.1 propcache-0.3.0 proto-plus-1.26.1 protobuf-5.29.3 psycopg2-binary-2.9.10 pyarrow-19.0.1 pyasn1-0.6.1 pyasn1-modules-0.4.1 pycparser-2.22 pydantic-2.10.6 pydantic-core-2.27.2 pydantic-settings-2.8.1 pyjwt-2.10.1 pylance-0.24.1 pypdf-5.3.1 pypdfium2-4.30.1 pypika-0.48.9 pyproject_hooks-1.2.0 pyright-1.1.396 pysbd-0.3.4 python-dotenv-1.0.1 pytube-15.0.0 pytz-2024.2 pyvis-0.3.2 qdrant-client-1.13.3 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rich-13.9.4 rpds-py-0.23.1 rsa-4.9 schema-0.7.7 setuptools-76.0.0 shapely-2.0.7 shellingham-1.5.4 sniffio-1.3.1 soupsieve-2.6 sqlalchemy-2.0.39 starlette-0.46.1 sympy-1.13.3 tabulate-0.9.0 tenacity-9.0.0 tiktoken-0.7.0 tokenizers-0.20.3 tomli-2.2.1 tomli-w-1.2.0 tqdm-4.67.1 typer-0.15.2 types-requests-2.32.0.20250306 typing-inspect-0.9.0 typing_extensions-4.12.2 tzdata-2025.1 urllib3-2.3.0 uv-0.6.6 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4 websocket-client-1.8.0 websockets-15.0.1 wrapt-1.17.2 yarl-1.18.3 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Configuration
#
# ### Agents
#
# > config/agents.yaml
#
# ### Tasks
#
# > config/tasks.yaml

# %%
from crewai import Agent, Crew, Process, Task
from crewai.project import CrewBase, agent, crew, task
from crewai_tools import SerperDevTool

@CrewBase
class ResearchCrew():
    """Research crew for comprehensive topic analysis and reporting"""

    agents_config = "config/agents.yaml"
    tasks_config = "config/tasks.yaml"

    @agent
    def researcher(self) -> Agent:
        return Agent(
            config=self.agents_config['researcher'],
            verbose=True,
            tools=[SerperDevTool()]
        )

    @agent
    def analyst(self) -> Agent:
        return Agent(
            config=self.agents_config['analyst'],
            verbose=True
        )

    @task
    def research_task(self) -> Task:
        return Task(
            config=self.tasks_config['research_task']
        )

    @task
    def analysis_task(self) -> Task:
        return Task(
            config=self.tasks_config['analysis_task'],
            output_file='output/report.md'
        )

    @crew
    def crew(self) -> Crew:
        """Creates the research crew"""
        return Crew(
            agents=self.agents,
            tasks=self.tasks,
            process=Process.sequential,
            verbose=True,
        )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 from crewai import Agent, Crew, Process, Task
#       2 from crewai.project import CrewBase, agent, crew, task
# ----> 3 from crewai_tools import SerperDevTool
#       5 @CrewBase
#       6 class ResearchCrew():
#       7     """Research crew for comprehensive topic analysis and reporting"""
#
# File ~/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages/crewai_tools/__init__.py:1
# ----> 1 from .tools import (
#       2     AIMindTool,
#       3     BraveSearchTool,
#       4     BrowserbaseLoadTool,
#       5     CodeDocsSearchTool,
#       6     CodeInterpreterTool,
#       7     ComposioTool,
#       8     CSVSearchTool,
#       9     DallETool,
#      10     DirectoryReadTool,
#      11     DirectorySearchTool,
#      12     DOCXSearchTool,
#      13     EXASearchTool,
#      14     FileReadTool,
#      15     FileWriterTool,
#      16     FirecrawlCrawlWebsiteTool,
#      17     FirecrawlScrapeWebsiteTool,
#      18     FirecrawlSearchTool,
#      19     GithubSearchTool,
#      20     HyperbrowserLoadTool,
#      21     JSONSearchTool,
#      22     LinkupSearchTool,
#      23     LlamaIndexTool,
#      24     MDXSearchTool,
#      25     MultiOnTool,
#      26     MySQLSearchTool,
#      27     NL2SQLTool,
#      28     PatronusEvalTool,
#      29     PatronusLocalEvaluatorTool,
#      30     PatronusPredefinedCriteriaEvalTool,
#      31     PDFSearchTool,
#      32     PGSearchTool,
#      33     QdrantVectorSearchTool,
#      34     RagTool,
#      35     ScrapeElementFromWebsiteTool,
#      36     ScrapegraphScrapeTool,
#      37     ScrapegraphScrapeToolSchema,
#      38     ScrapeWebsiteTool,
#      39     ScrapflyScrapeWebsiteTool,
#      40     SeleniumScrapingTool,
#      41     SerpApiGoogleSearchTool,
#      42     SerpApiGoogleShoppingTool,
#      43     SerperDevTool,
#      44     SerplyJobSearchTool,
#      45     SerplyNewsSearchTool,
#      46     SerplyScholarSearchTool,
#      47     SerplyWebpageToMarkdownTool,
#      48     SerplyWebSearchTool,
#      49     SnowflakeConfig,
#      50     SnowflakeSearchTool,
#      51     SpiderTool,
#      52     TXTSearchTool,
#      53     VisionTool,
#      54     WeaviateVectorSearchTool,
#      55     WebsiteSearchTool,
#      56     XMLSearchTool,
#      57     YoutubeChannelSearchTool,
#      58     YoutubeVideoSearchTool,
#      59 )
#
# File ~/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages/crewai_tools/tools/__init__.py:14
#      12 from .exa_tools.exa_search_tool import EXASearchTool
#      13 from .file_read_tool.file_read_tool import FileReadTool
# ---> 14 from .file_writer_tool.file_writer_tool import FileWriterTool
#      15 from .firecrawl_crawl_website_tool.firecrawl_crawl_website_tool import (
#      16     FirecrawlCrawlWebsiteTool,
#      17 )
#      18 from .firecrawl_scrape_website_tool.firecrawl_scrape_website_tool import (
#      19     FirecrawlScrapeWebsiteTool,
#      20 )
#
# File ~/my-workspaces/genai-samples/.venv/lib/python3.12/site-packages/crewai_tools/tools/file_writer_tool/file_writer_tool.py:2
#       1 import os
# ----> 2 from distutils.util import strtobool
#       3 from typing import Any, Optional, Type
#       5 from crewai.tools import BaseTool
#
# ModuleNotFoundError: No module named 'distutils'

# %%
crew = ResearchCrew()
crew.kickoff()
